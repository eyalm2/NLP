# %%
# !pip -q install -U "transformers>=4.46.0" "peft>=0.13.0" "accelerate>=1.0.0" "torchao>=0.16.0" scikit-learn safetensors tqdm

from google.colab import drive
drive.mount('/content/drive')

import os, math, random
from copy import deepcopy
from collections import defaultdict, Counter
from itertools import product

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, Sampler

from transformers import AutoTokenizer, AutoModelForCausalLM, get_linear_schedule_with_warmup
from peft import LoraConfig, get_peft_model, TaskType

os.environ["TOKENIZERS_PARALLELISM"] = "false"

import json, csv, time, gc

TEST_ROOT = "/content/drive/MyDrive/Test"
OUT_DIR = os.path.join(TEST_ROOT, "Python", "test_bridge_simple")
os.makedirs(OUT_DIR, exist_ok=True)

MODEL_NAME = "EleutherAI/pythia-1.4b-deduped"
SEED = 42
DATA_SEED = 42
SPLIT_SEED = 42
TRAIN_SEED_BASE = 42
EPOCHS = 15
TRAIN_FRAC = 0.85

BATCH_SIZE = 16
LR = 5e-5
MAX_LENGTH = 256

CONTRASTIVE_LAMBDA = 1000.0

WEIGHT_DECAY = 0.01
WARMUP_RATIO = 0.05
GRAD_ACCUM = 1
MAX_GRAD_NORM = 1.0

CROSS_N_INPUT_BLOCK_EXTRAS = 2

USE_ROLE_CONFUSION_ROWS = True

LORA_R = 64
LORA_ALPHA = 64
LORA_DROPOUT = 0.10
LORA_TARGET_MODULES = ["query_key_value", "dense", "dense_h_to_4h", "dense_4h_to_h"]

VARS = ["a", "b", "c", "d"]
OPS = ["or", "and", "iff"]
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

RUNS = [
    {
        "idx": 0,
        "name": "baseline",
        "full_prompt_rows": 0,
        "format_row_weight": 1,
        "contrastive_scale": 1.0,
        "temperature": 0.05,
        "pooling": "last",
    },
    {
        "idx": 1,
        "name": "full_prompts_50",
        "full_prompt_rows": 50,
        "format_row_weight": 1,
        "contrastive_scale": 1.0,
        "temperature": 0.05,
        "pooling": "last",
    },
    {
        "idx": 3,
        "name": "format_2x",
        "full_prompt_rows": 0,
        "format_row_weight": 2,
        "contrastive_scale": 1.0,
        "temperature": 0.05,
        "pooling": "last",
    },
    {
        "idx": 4,
        "name": "full_prompts_50_format_2x",
        "full_prompt_rows": 50,
        "format_row_weight": 2,
        "contrastive_scale": 1.0,
        "temperature": 0.05,
        "pooling": "last",
    },
    {
        "idx": 5,
        "name": "contrastive_0p5x",
        "full_prompt_rows": 0,
        "format_row_weight": 1,
        "contrastive_scale": 0.5,
        "temperature": 0.05,
        "pooling": "last",
    },
    {
        "idx": 6,
        "name": "contrastive_2x",
        "full_prompt_rows": 0,
        "format_row_weight": 1,
        "contrastive_scale": 2.0,
        "temperature": 0.05,
        "pooling": "last",
    },
    {
        "idx": 9,
        "name": "mean_pooling",
        "full_prompt_rows": 0,
        "format_row_weight": 1,
        "contrastive_scale": 1.0,
        "temperature": 0.05,
        "pooling": "mean",
    },
]

RUN_IDS = {0, 1, 3, 4, 5, 6, 9}

print("OUT_DIR:", OUT_DIR)
print("DEVICE:", DEVICE)
print("variants:", [v["name"] for v in RUNS if v["idx"] in RUN_IDS])
print("shared settings:", {
    "epochs": EPOCHS,
    "lr": LR,
    "batch_size": BATCH_SIZE,
    "max_length": MAX_LENGTH,
    "base_contrastive_lambda": CONTRASTIVE_LAMBDA,
    "lora_r": LORA_R,
    "lora_alpha": LORA_ALPHA,
    "cross_n_input_block_extras": CROSS_N_INPUT_BLOCK_EXTRAS,
    "use_role_confusion_rows": USE_ROLE_CONFUSION_ROWS,
    "data_seed": DATA_SEED,
    "split_seed": SPLIT_SEED,
    "train_seed_base": TRAIN_SEED_BASE,
})
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# WARNING:torchao:Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# OUT_DIR: /content/drive/MyDrive/Test/Python/test_bridge_simple
# DEVICE: cuda
# variants: ['baseline', 'full_prompts_50', 'format_2x', 'full_prompts_50_format_2x', 'contrastive_0p5x', 'contrastive_2x', 'mean_pooling']
# shared settings: {'epochs': 15, 'lr': 5e-05, 'batch_size': 16, 'max_length': 256, 'base_contrastive_lambda': 1000.0, 'lora_r': 64, 'lora_alpha': 64, 'cross_n_input_block_extras': 2, 'use_role_confusion_rows': True, 'data_seed': 42, 'split_seed': 42, 'train_seed_base': 42}

# %%
def set_seed(seed):
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

def bool_word(x):
    return "True" if x else "False"

def masked_mean(x, mask):
    if mask.any():
        return x[mask].mean().item()
    return float("nan")

def var_list(n):
    return VARS[:n]

def symbol_status(v, val):
    return f"{v} is defined as: {bool_word(val)}"

def Atom(v, neg=False):
    return ("atom", v, bool(neg))

def Bin(op, left_atom, right_atom):
    return ("bin", op, left_atom, right_atom)

def atom_key(atom):
    _, v, neg = atom
    return f"not_{v}" if neg else v

def lit_sort_key(atom):
    _, v, neg = atom
    return (v, int(neg))

def expr_surface_id(expr):
    if expr[0] == "atom":
        return atom_key(expr)
    _, op, a1, a2 = expr
    return f"{op}({atom_key(a1)},{atom_key(a2)})"

def expr_vars(expr):
    if expr[0] == "atom":
        return (expr[1],)
    _, _, a1, a2 = expr
    return tuple(sorted({a1[1], a2[1]}))

def eval_atom(atom, env):
    _, v, neg = atom
    val = bool(env[v])
    return (not val) if neg else val

def eval_expr(expr, env):
    if expr[0] == "atom":
        return eval_atom(expr, env)

    _, op, a1, a2 = expr
    x = eval_atom(a1, env)
    y = eval_atom(a2, env)

    if op == "and":
        return x and y
    if op == "or":
        return x or y
    if op == "iff":
        return x == y
    raise ValueError(op)

def expr_truth_table(expr):
    vars_ = expr_vars(expr)
    bits = []
    for vals in product([False, True], repeat=len(vars_)):
        env = dict(zip(vars_, vals))
        bits.append("1" if eval_expr(expr, env) else "0")
    return vars_, "".join(bits)

def expr_canonical_id(expr):
    return f"surface|{expr_surface_id(expr)}"

def expr_equiv_id(expr):
    vars_, table = expr_truth_table(expr)
    return f"truth|vars={','.join(vars_)}|tt={table}"

def render_atom(atom, surface):
    _, v, neg = atom
    if surface == "python":
        return f"(not {v})" if neg else v
    return f"not {v}" if neg else v

def render_expr(expr, surface):
    if expr[0] == "atom":
        return render_atom(expr, surface)

    _, op, a1, a2 = expr
    left = render_atom(a1, surface)
    right = render_atom(a2, surface)

    if surface == "python":
        if op == "or":
            return f"{left} or {right}"
        if op == "and":
            return f"{left} and {right}"
        if op == "iff":
            return f"{left} == {right}"
        raise ValueError(op)

    if op == "or":
        return f"either {left} or {right}"
    if op == "and":
        return f"both {left} and {right}"
    if op == "iff":
        return f"{left} if and only if {right}"
    raise ValueError(op)

def make_text(expr, surface, text_mode, speaker_idx=0):
    body = render_expr(expr, surface)
    if text_mode == "expr":
        return body
    if text_mode == "rule":
        if surface == "python":
            return f"rule_{speaker_idx + 1} = {body}"
        return f"rule_{speaker_idx + 1} is defined as: {body}"
    raise ValueError(text_mode)

def build_atoms(vars_):
    out = []
    for v in vars_:
        out.append(Atom(v, False))
        out.append(Atom(v, True))
    return out

def build_exprs():
    atoms = build_atoms(VARS)
    exprs = []
    exprs.extend(atoms)

    for op in OPS:
        for a1 in atoms:
            for a2 in atoms:
                exprs.append(Bin(op, a1, a2))

    seen = set()
    deduped = []
    for e in exprs:
        sid = expr_surface_id(e)
        if sid not in seen:
            seen.add(sid)
            deduped.append(e)
    return deduped

def expr_meta(expr):
    vars_used, truth_table = expr_truth_table(expr)
    canonical = expr_canonical_id(expr)
    equiv = expr_equiv_id(expr)

    if expr[0] == "atom":
        _, v, neg = expr
        return {
            "kind": "atom",
            "var": v,
            "neg": int(neg),
            "vars_used": vars_used,
            "truth_table": truth_table,
            "op": None,
            "same_variable": 0,
            "surface": expr_surface_id(expr),
            "canonical": canonical,
            "equiv": equiv,
        }

    _, op, a1, a2 = expr
    ordered_lits = ((a1[1], int(a1[2])), (a2[1], int(a2[2])))
    return {
        "kind": "bin",
        "op": op,
        "vars_ordered": tuple(v for v, _ in ordered_lits),
        "negs_ordered": tuple(n for _, n in ordered_lits),
        "vars_used": vars_used,
        "truth_table": truth_table,
        "same_variable": int(a1[1] == a2[1]),
        "surface": expr_surface_id(expr),
        "canonical": canonical,
        "equiv": equiv,
    }

def batch_bucket_key(meta):
    if meta["kind"] == "format":
        ft = meta["format_type"]
        if ft in {"input_block", "full_prompt", "full_prompt_val"}:
            return ("format", ft, meta["n"])
        return ("format", ft)

    if meta["kind"] == "atom":
        return ("logic", meta["text_mode"], "atom", meta["var"])

    if meta["kind"] == "bin" and meta.get("same_variable") == 1:
        return ("logic", meta["text_mode"], "samevar", meta["op"], meta["vars_ordered"][0])

    return ("logic", meta["text_mode"], "bin_ordered_vars", meta["vars_ordered"])

def add_row(rows, semantic_id, canonical_id, equiv_id, text_en, text_py, meta):
    meta = dict(meta)
    rows.append({
        "semantic_id": semantic_id,
        "canonical_id": canonical_id,
        "equiv_id": equiv_id,
        "text_en": text_en,
        "text_py": text_py,
        "meta": meta,
        "bucket_key": batch_bucket_key(meta),
        "contrastive_ok": True,
    })

def build_format_rows():
    rows = []

    for n in [2, 3, 4]:
        sid = f"format|header|n={n}"
        header = "\n".join([
            "Instruction:",
            "Evaluate the rules on the given input.",
            "Output only: True or False.",
            "",
            "Rules:",
        ])
        add_row(
            rows,
            semantic_id=sid,
            canonical_id=sid,
            equiv_id=sid,
            text_py=header,
            text_en=header,
            meta={"kind": "format", "text_mode": "format", "format_type": "header", "n": n},
        )

    for i, v in enumerate(VARS):
        sid = f"format|return_condition|idx={i}"
        add_row(
            rows,
            semantic_id=sid,
            canonical_id=sid,
            equiv_id=sid,
            text_py=f"{v} == rule_{i + 1}",
            text_en=f"{v} is True if and only if rule_{i + 1} is True",
            meta={"kind": "format", "text_mode": "format", "format_type": "return_condition", "idx": i},
        )

    for n in [2, 3, 4]:
        vars_ = var_list(n)
        text_py = "    return " + " and ".join(f"{v} == rule_{i + 1}" for i, v in enumerate(vars_))
        conditions = [
            f"{v} is True if and only if rule_{i + 1} is True"
            for i, v in enumerate(vars_)
        ]
        text_en = "The output states whether: " + " and ".join(conditions) + "."
        sid = f"format|return_block|n={n}"
        add_row(
            rows,
            semantic_id=sid,
            canonical_id=sid,
            equiv_id=sid,
            text_py=text_py,
            text_en=text_en,
            meta={"kind": "format", "text_mode": "format", "format_type": "return_block", "n": n},
        )

    for i, v in enumerate(VARS):
        for val in [False, True]:
            sid = f"format|input_line|idx={i}|val={int(val)}"
            add_row(
                rows,
                semantic_id=sid,
                canonical_id=sid,
                equiv_id=sid,
                text_py=f"{v} = {bool_word(val)}",
                text_en=symbol_status(v, val),
                meta={"kind": "format", "text_mode": "format", "format_type": "input_line", "idx": i, "val": int(val)},
            )

    for n in [2, 3, 4]:
        vars_ = var_list(n)
        for assign in product([False, True], repeat=n):
            key = "".join("1" if x else "0" for x in assign)
            py_lines = ["Input:"]
            en_lines = ["Input:"]
            for v, val in zip(vars_, assign):
                py_lines.append(f"{v} = {bool_word(val)}")
                en_lines.append(symbol_status(v, val))

            sid = f"format|input_block|n={n}|assign={key}"
            add_row(
                rows,
                semantic_id=sid,
                canonical_id=sid,
                equiv_id=sid,
                text_py="\n".join(py_lines),
                text_en="\n".join(en_lines),
                meta={"kind": "format", "text_mode": "format", "format_type": "input_block", "n": n, "assign": key},
            )

    return rows

def expr_allowed_for_n(expr, n):
    return set(expr_vars(expr)).issubset(set(var_list(n)))

def render_full_prompt(n, rule_exprs, assign):
    vars_ = var_list(n)

    py_lines = [
        "Instruction:",
        "Evaluate the rules on the given input.",
        "Output only: True or False.",
        "",
        "Rules:",
    ]

    for i, expr in enumerate(rule_exprs):
        py_lines.append(make_text(expr, "python", "rule", i))

    py_lines.append("")
    py_lines.append("    return " + " and ".join(f"{v} == rule_{i + 1}" for i, v in enumerate(vars_)))
    py_lines.append("")
    py_lines.append("Input:")

    for v, val in zip(vars_, assign):
        py_lines.append(f"{v} = {bool_word(val)}")

    py_lines.append("")
    py_lines.append("Output:")

    en_lines = [
        "Instruction:",
        "Evaluate the rules on the given input.",
        "Output only: True or False.",
        "",
        "Rules:",
    ]

    for i, expr in enumerate(rule_exprs):
        en_lines.append(make_text(expr, "english", "rule", i))

    conditions = [
        f"{v} is True if and only if rule_{i + 1} is True"
        for i, v in enumerate(vars_)
    ]

    en_lines.append("")
    en_lines.append("The output states whether: " + " and ".join(conditions) + ".")
    en_lines.append("")
    en_lines.append("Input:")

    for v, val in zip(vars_, assign):
        en_lines.append(symbol_status(v, val))

    en_lines.append("")
    en_lines.append("Output:")

    return "\n".join(py_lines), "\n".join(en_lines)

def build_full_prompt_rows(num_rows, seed):
    if num_rows <= 0:
        return []

    rng = random.Random(seed + 10000)
    rows = []
    exprs_all = build_exprs()
    exprs_by_n = {
        n: [e for e in exprs_all if expr_allowed_for_n(e, n)]
        for n in [2, 3, 4]
    }

    seen = set()
    attempts = 0
    while len(rows) < num_rows and attempts < num_rows * 200:
        attempts += 1
        n = rng.choice([2, 3, 4])
        exprs_n = exprs_by_n[n]
        rule_exprs = [rng.choice(exprs_n) for _ in range(n)]
        assign = tuple(rng.choice([False, True]) for _ in range(n))
        assign_key = "".join("1" if x else "0" for x in assign)

        surface_parts = [expr_surface_id(e) for e in rule_exprs]
        canon_parts = [expr_canonical_id(e) for e in rule_exprs]
        equiv_parts = [expr_equiv_id(e) for e in rule_exprs]

        semantic_id = f"full_prompt|n={n}|rules={'/'.join(surface_parts)}|assign={assign_key}"
        if semantic_id in seen:
            continue
        seen.add(semantic_id)

        canonical_id = f"full_prompt|n={n}|rules={'/'.join(canon_parts)}|assign={assign_key}"
        equiv_id = f"full_prompt|n={n}|rules={'/'.join(equiv_parts)}|assign={assign_key}"

        text_py, text_en = render_full_prompt(n, rule_exprs, assign)
        add_row(
            rows,
            semantic_id=semantic_id,
            canonical_id=canonical_id,
            equiv_id=equiv_id,
            text_en=text_en,
            text_py=text_py,
            meta={
                "kind": "format",
                "text_mode": "format",
                "format_type": "full_prompt",
                "n": n,
                "assign": assign_key,
            },
        )

    assert len(rows) == num_rows, f"Could only build {len(rows)} full prompt rows out of requested {num_rows}"
    return rows

def build_full_prompt_val_rows():
    specs = [
        (2, [Atom("a"), Atom("b", True)], (True, False)),
        (3, [
            Bin("and", Atom("a"), Atom("b")),
            Bin("or", Atom("b", True), Atom("c")),
            Bin("iff", Atom("a"), Atom("c", True)),
        ], (True, False, True)),
        (4, [
            Bin("iff", Atom("a"), Atom("b")),
            Bin("and", Atom("c"), Atom("d", True)),
            Bin("or", Atom("a", True), Atom("d")),
            Atom("c", True),
        ], (False, True, False, True)),
    ]

    rows = []
    for case_idx, (n, rule_exprs, assign) in enumerate(specs):
        assign_key = "".join("1" if x else "0" for x in assign)
        surface_parts = [expr_surface_id(e) for e in rule_exprs]
        canon_parts = [expr_canonical_id(e) for e in rule_exprs]
        equiv_parts = [expr_equiv_id(e) for e in rule_exprs]

        sid = f"format|full_prompt_val|n={n}|case={case_idx}"
        canonical_id = f"full_prompt|n={n}|rules={'/'.join(canon_parts)}|assign={assign_key}"
        equiv_id = f"full_prompt|n={n}|rules={'/'.join(equiv_parts)}|assign={assign_key}"

        text_py, text_en = render_full_prompt(n, rule_exprs, assign)
        add_row(
            rows,
            semantic_id=sid,
            canonical_id=canonical_id,
            equiv_id=equiv_id,
            text_en=text_en,
            text_py=text_py,
            meta={"kind": "format", "text_mode": "format", "format_type": "full_prompt_val", "n": n, "case": case_idx},
        )
    return rows

def build_rows(cfg=None):
    cfg = cfg or {}
    rows = []
    exprs = build_exprs()

    for expr in exprs:
        surface = expr_surface_id(expr)
        canonical = expr_canonical_id(expr)
        meta0 = expr_meta(expr)

        meta = {**meta0, "text_mode": "expr"}
        add_row(
            rows,
            semantic_id=f"expr|{surface}",
            canonical_id=f"expr|{canonical}",
            equiv_id=f"expr|{meta0['equiv']}",
            text_en=make_text(expr, "english", "expr"),
            text_py=make_text(expr, "python", "expr"),
            meta=meta,
        )

        for speaker_idx in range(len(VARS)):
            meta = {**meta0, "text_mode": "rule", "speaker_idx": speaker_idx}
            add_row(
                rows,
                semantic_id=f"rule|{surface}|speaker={speaker_idx}",
                canonical_id=f"rule|{canonical}|speaker={speaker_idx}",
                equiv_id=f"rule|{meta0['equiv']}|speaker={speaker_idx}",
                text_en=make_text(expr, "english", "rule", speaker_idx),
                text_py=make_text(expr, "python", "rule", speaker_idx),
                meta=meta,
            )

    rows.extend(build_format_rows())

    full_prompt_rows = int(cfg.get("full_prompt_rows", 0))
    if full_prompt_rows > 0:
        rows.extend(build_full_prompt_rows(full_prompt_rows, int(cfg.get("seed", SEED))))

    return rows

def build_role_confusion_views(source_rows):
    by_semantic = {}
    for r in source_rows:
        by_semantic.setdefault(r["semantic_id"], r)

    confusion_rows = []
    seen = set()

    def atom_sem(v, neg=False):
        return f"expr|{expr_surface_id(Atom(v, neg))}"

    def rule_atom_sem(v, neg, speaker_idx):
        return f"rule|{expr_surface_id(Atom(v, neg))}|speaker={speaker_idx}"

    def input_line_sem(idx, val):
        return f"format|input_line|idx={idx}|val={int(val)}"

    def return_condition_sem(idx):
        return f"format|return_condition|idx={idx}"

    def iff_expr_sem(v, w):
        return f"expr|{expr_surface_id(Bin('iff', Atom(v, False), Atom(w, False)))}"

    def add_view(semantic_id, confusion_type, bucket_parts):
        base = by_semantic.get(semantic_id)
        if base is None:
            return
        bucket_key = ("role_confusion", confusion_type) + tuple(bucket_parts)
        key = (semantic_id, bucket_key)
        if key in seen:
            return
        seen.add(key)

        rr = deepcopy(base)
        rr["meta"] = dict(rr["meta"])
        rr["meta"]["role_confusion_view"] = 1
        rr["meta"]["confusion_type"] = confusion_type
        rr["bucket_key"] = bucket_key
        rr["contrastive_ok"] = True
        confusion_rows.append(rr)

    def add_bucket(semantic_ids, confusion_type, bucket_parts):
        before = len(confusion_rows)
        for sid in semantic_ids:
            add_view(sid, confusion_type, bucket_parts)

        added = confusion_rows[before:]
        if len({r["canonical_id"] for r in added}) < 2:
            del confusion_rows[before:]

    for idx, v in enumerate(VARS):
        add_bucket(
            [input_line_sem(idx, True), atom_sem(v, False)],
            "input_vs_atom",
            (v, "true"),
        )
        add_bucket(
            [input_line_sem(idx, False), atom_sem(v, True)],
            "input_vs_atom",
            (v, "false"),
        )

    for idx, v in enumerate(VARS):
        for speaker_idx in range(len(VARS)):
            add_bucket(
                [input_line_sem(idx, True), rule_atom_sem(v, False, speaker_idx)],
                "input_vs_rule_atom",
                (v, "true", f"speaker={speaker_idx}"),
            )
            add_bucket(
                [input_line_sem(idx, False), rule_atom_sem(v, True, speaker_idx)],
                "input_vs_rule_atom",
                (v, "false", f"speaker={speaker_idx}"),
            )

    for v in VARS:
        for neg in [False, True]:
            sign = "neg" if neg else "pos"
            for speaker_idx in range(len(VARS)):
                add_bucket(
                    [atom_sem(v, neg), rule_atom_sem(v, neg, speaker_idx)],
                    "expr_vs_rule_atom",
                    (v, sign, f"speaker={speaker_idx}"),
                )

    for idx, v in enumerate(VARS):
        add_bucket(
            [
                return_condition_sem(idx),
                rule_atom_sem(v, False, idx),
                rule_atom_sem(v, True, idx),
            ],
            "rule_atom_vs_return_condition",
            (v, f"rule={idx + 1}"),
        )

    for idx, v in enumerate(VARS):
        ids = [return_condition_sem(idx)]
        ids.extend(iff_expr_sem(v, w) for w in VARS)
        add_bucket(
            ids,
            "iff_expr_vs_return_condition",
            (v, f"return={idx + 1}"),
        )

    for i in range(len(VARS)):
        for j in range(i + 1, len(VARS)):
            vi, vj = VARS[i], VARS[j]
            for neg in [False, True]:
                sign = "neg" if neg else "pos"
                add_bucket(
                    [
                        rule_atom_sem(vj, neg, i),
                        rule_atom_sem(vi, neg, j),
                    ],
                    "speaker_content_swap",
                    (f"speaker={i}_content={vj}", f"speaker={j}_content={vi}", sign),
                )

    return confusion_rows

def important_format_val_ids(rows):
    out = set()
    keep_input_lines = {
        (0, 0), (0, 1),
        (1, 0), (1, 1),
    }
    keep_input_blocks = {
        (2, "01"),
        (3, "010"),
        (4, "0101"),
        (4, "0000"),
        (4, "1111"),
    }

    for r in rows:
        m = r["meta"]
        if m.get("kind") != "format":
            continue

        ft = m.get("format_type")
        if ft == "header" and m.get("n") == 3:
            out.add(r["canonical_id"])
        elif ft == "return_block" and m.get("n") == 3:
            out.add(r["canonical_id"])
        elif ft == "return_condition" and m.get("idx") in {0, 2}:
            out.add(r["canonical_id"])
        elif ft == "input_line" and (m.get("idx"), m.get("val")) in keep_input_lines:
            out.add(r["canonical_id"])
        elif ft == "input_block" and (m.get("n"), m.get("assign")) in keep_input_blocks:
            out.add(r["canonical_id"])
    return out

def split_rows(rows, seed=SEED, force_val_ids=None):
    force_val_ids = set(force_val_ids or [])
    format_ids = {r["canonical_id"] for r in rows if r["meta"].get("kind") == "format"}
    random_ids = sorted({
        r["canonical_id"] for r in rows
        if r["canonical_id"] not in force_val_ids and r["canonical_id"] not in format_ids
    })
    rng = random.Random(seed)
    rng.shuffle(random_ids)
    cut = max(1, int(len(random_ids) * TRAIN_FRAC))
    train_ids = set(random_ids[:cut]) | (format_ids - force_val_ids)
    val_ids = set(random_ids[cut:]) | force_val_ids
    return [r for r in rows if r["canonical_id"] in train_ids], [r for r in rows if r["canonical_id"] in val_ids]

class PairDataset(Dataset):
    def __init__(self, rows):
        self.rows = rows
    def __len__(self):
        return len(self.rows)
    def __getitem__(self, idx):
        return self.rows[idx]

class PairCollator:
    def __init__(self, tokenizer):
        self.tok = tokenizer

    def tokenize(self, texts):
        enc = self.tok(
            texts,
            padding=True,
            truncation=True,
            max_length=MAX_LENGTH,
            return_tensors="pt",
        )
        labels = enc["input_ids"].clone()
        labels[enc["attention_mask"] == 0] = -100
        enc["labels"] = labels
        return enc

    def __call__(self, batch):
        en = [x["text_en"] for x in batch]
        py = [x["text_py"] for x in batch]
        enc_en = self.tokenize(en)
        enc_py = self.tokenize(py)
        return {
            "en": enc_en,
            "py": enc_py,
            "semantic_ids": [x["semantic_id"] for x in batch],
            "canonical_ids": [x["canonical_id"] for x in batch],
            "equiv_ids": [x["equiv_id"] for x in batch],
            "bucket_keys": [x["bucket_key"] for x in batch],
            "contrastive_ok": [x["contrastive_ok"] for x in batch],
        }

class BucketSampler(Sampler):
    def __init__(self, rows, batch_size, seed):
        self.rows = rows
        self.batch_size = batch_size
        self.seed = seed
        self.epoch = 0
        self.by_bucket = defaultdict(list)
        for idx, r in enumerate(rows):
            self.by_bucket[r["bucket_key"]].append(idx)

        self.input_block_keys = [k for k in self.by_bucket if len(k) == 3 and k[0] == "format" and k[1] == "input_block"]

    def set_epoch(self, epoch):
        self.epoch = epoch

    def _has_two_canonical_groups(self, batch):
        return len({self.rows[i]["canonical_id"] for i in batch}) >= 2

    def _sample_cross_n_input_blocks(self, key, core_len, rng):
        if CROSS_N_INPUT_BLOCK_EXTRAS <= 0 or core_len <= 0:
            return []
        extra_count = min(CROSS_N_INPUT_BLOCK_EXTRAS, max(1, core_len // 4))
        other = []
        for k in self.input_block_keys:
            if k != key:
                other.extend(self.by_bucket[k])
        rng.shuffle(other)
        return other[:extra_count]

    def __iter__(self):
        rng = random.Random(self.seed + self.epoch)
        batches = []

        for key, idxs0 in self.by_bucket.items():
            idxs = idxs0[:]
            rng.shuffle(idxs)

            is_input_block = len(key) == 3 and key[0] == "format" and key[1] == "input_block"
            if is_input_block:
                bucket_batch_size = max(2, self.batch_size - CROSS_N_INPUT_BLOCK_EXTRAS)
                for start in range(0, len(idxs), bucket_batch_size):
                    core = idxs[start:start + bucket_batch_size]
                    batch = core + self._sample_cross_n_input_blocks(key, len(core), rng)
                    if self._has_two_canonical_groups(batch):
                        batches.append(batch)
            else:
                for start in range(0, len(idxs), self.batch_size):
                    batch = idxs[start:start + self.batch_size]
                    if self._has_two_canonical_groups(batch):
                        batches.append(batch)

        rng.shuffle(batches)
        for b in batches:
            yield b

    def __len__(self):
        return sum(1 for _ in self.__iter__())

class PairModel(nn.Module):
    def __init__(self, lm, pooling="last"):
        super().__init__()
        assert pooling in {"last", "mean"}
        self.lm = lm
        self.pooling = pooling

    def encode_with_ce(self, enc):
        out = self.lm(
            input_ids=enc["input_ids"],
            attention_mask=enc["attention_mask"],
            labels=enc["labels"],
            output_hidden_states=True,
            return_dict=True,
        )
        h = out.hidden_states[-1]

        if self.pooling == "last":
            last_idx = enc["attention_mask"].sum(dim=1) - 1
            batch_idx = torch.arange(h.size(0), device=h.device)
            z = h[batch_idx, last_idx]
        else:
            mask = enc["attention_mask"].unsqueeze(-1).to(h.dtype)
            z = (h * mask).sum(dim=1) / mask.sum(dim=1).clamp_min(1.0)

        z = F.normalize(z, p=2, dim=-1)
        return z, out.loss

    def forward(self, enc_en, enc_py):
        z_en, ce_en = self.encode_with_ce(enc_en)
        z_py, ce_py = self.encode_with_ce(enc_py)
        ce_loss = 0.5 * (ce_en + ce_py)
        return z_en, z_py, ce_loss

def to_device(enc, device):
    return {k: v.to(device) for k, v in enc.items()}

def make_model(pooling="last"):
    tok = AutoTokenizer.from_pretrained(MODEL_NAME)
    tok.padding_side = "right"
    if tok.pad_token is None:
        tok.pad_token = tok.eos_token

    dtype = torch.float16 if DEVICE == "cuda" else torch.float32
    lm = AutoModelForCausalLM.from_pretrained(MODEL_NAME, torch_dtype=dtype)
    lm.config.use_cache = False
    lm.gradient_checkpointing_enable()

    lora_cfg = LoraConfig(
        task_type=TaskType.CAUSAL_LM,
        r=LORA_R,
        lora_alpha=LORA_ALPHA,
        lora_dropout=LORA_DROPOUT,
        target_modules=LORA_TARGET_MODULES,
        bias="none",
    )
    lm = get_peft_model(lm, lora_cfg)
    lm.enable_input_require_grads()
    lm.print_trainable_parameters()

    return PairModel(lm, pooling=pooling).to(DEVICE), tok

def _id_equal_mask(ids, device):
    n = len(ids)
    mask = torch.zeros((n, n), dtype=torch.bool, device=device)
    for i in range(n):
        for j in range(n):
            if ids[i] == ids[j]:
                mask[i, j] = True
    return mask

def _allowed_mask_from_ids(canonical_ids, equiv_ids, device):
    pos = _id_equal_mask(canonical_ids, device)
    same_equiv = _id_equal_mask(equiv_ids, device)
    allowed = pos | (~same_equiv)
    return allowed, pos

def _multi_positive_ce(sim, pos_mask, allowed_mask):
    very_neg = torch.finfo(sim.dtype).min
    sim_allowed = sim.masked_fill(~allowed_mask, very_neg)
    sim_pos = sim.masked_fill(~pos_mask, very_neg)
    log_num = torch.logsumexp(sim_pos, dim=1)
    log_den = torch.logsumexp(sim_allowed, dim=1)
    return -(log_num - log_den).mean()

def contrastive_loss(z_en, z_py, canonical_ids, equiv_ids, contrastive_ok, temperature):
    keep = torch.tensor(contrastive_ok, dtype=torch.bool, device=z_en.device)

    if keep.sum().item() < 2:
        zero = z_en.new_zeros(())
        return zero, None, None, None

    can = [cid for cid, ok in zip(canonical_ids, contrastive_ok) if ok]
    eqv = [eid for eid, ok in zip(equiv_ids, contrastive_ok) if ok]
    if len(set(can)) < 2:
        zero = z_en.new_zeros(())
        return zero, None, None, None

    z_en_k = z_en[keep]
    z_py_k = z_py[keep]
    sim = (z_en_k @ z_py_k.T) / temperature
    allowed, pos_mask = _allowed_mask_from_ids(can, eqv, sim.device)

    if ((allowed & ~pos_mask).sum().item()) == 0:
        zero = z_en.new_zeros(())
        return zero, sim, pos_mask, allowed

    loss_en_to_py = _multi_positive_ce(sim, pos_mask, allowed)
    loss_py_to_en = _multi_positive_ce(sim.T, pos_mask.T, allowed.T)
    return 0.5 * (loss_en_to_py + loss_py_to_en), sim, pos_mask, allowed

def bridge_loss(ce_loss, contrastive_loss, contrastive_lambda, contrastive_scale):
    ratio = ce_loss.detach() / contrastive_loss.detach().clamp_min(1e-8)
    weight = torch.clamp(ratio, max=contrastive_lambda)
    total = ce_loss + contrastive_scale * weight * contrastive_loss
    return total, weight * contrastive_scale

@torch.no_grad()
def eval_model(model, rows, tok):
    model.eval()
    collator = PairCollator(tok)
    loader = DataLoader(PairDataset(rows), batch_size=BATCH_SIZE, shuffle=False, collate_fn=collator)

    all_en, all_py, all_semantic, all_canonical, all_equiv, all_ok = [], [], [], [], [], []
    ce_total = 0.0
    ce_n = 0

    for batch in loader:
        z_en, z_py, ce = model(to_device(batch["en"], DEVICE), to_device(batch["py"], DEVICE))
        bsz = len(batch["semantic_ids"])
        all_en.append(z_en.cpu())
        all_py.append(z_py.cpu())
        all_semantic.extend(batch["semantic_ids"])
        all_canonical.extend(batch["canonical_ids"])
        all_equiv.extend(batch["equiv_ids"])
        all_ok.extend(batch["contrastive_ok"])
        ce_total += ce.item() * bsz
        ce_n += bsz

    z_en = torch.cat(all_en, dim=0)
    z_py = torch.cat(all_py, dim=0)

    ok_idx = [i for i, ok in enumerate(all_ok) if ok]
    if len(ok_idx) >= 2:
        z_en_ok = z_en[ok_idx]
        z_py_ok = z_py[ok_idx]
        sem_ok = [all_semantic[i] for i in ok_idx]
        can_ok = [all_canonical[i] for i in ok_idx]
        eqv_ok = [all_equiv[i] for i in ok_idx]

        sim = z_en_ok @ z_py_ok.T
        allowed, pos_mask = _allowed_mask_from_ids(can_ok, eqv_ok, sim.device)
        sim_rank = sim.masked_fill(~allowed, torch.finfo(sim.dtype).min)
        top1 = sim_rank.argmax(dim=1)
        canonical_top1 = sum(can_ok[i] == can_ok[top1[i].item()] for i in range(len(can_ok))) / len(can_ok)

        pos_mask = pos_mask.cpu()
        allowed = allowed.cpu()
        neg_mask = allowed & ~pos_mask
        mean_pos = masked_mean(sim, pos_mask)
        mean_neg = masked_mean(sim, neg_mask)
    else:
        canonical_top1 = float("nan")
        mean_pos = float("nan")
        mean_neg = float("nan")

    return {
        "top1_canonical": canonical_top1,
        "mean_pos_sim": mean_pos,
        "mean_neg_sim": mean_neg,
        "ce": ce_total / ce_n,
        "contrastive_rows": len(ok_idx),
        "ce_only_rows": len(all_ok) - len(ok_idx),
    }

def rows_summary(rows):
    counts = Counter()
    for r in rows:
        if r["meta"].get("role_confusion_view"):
            counts["role_confusion_views"] += 1
            counts[f"role_confusion_{r['meta'].get('confusion_type', 'unknown')}"] += 1

        if r["semantic_id"].startswith("expr|"):
            counts["expr"] += 1
        elif r["semantic_id"].startswith("rule|"):
            counts["rule"] += 1
        elif r["meta"].get("kind") == "format":
            counts["format"] += 1
            counts[f"format_{r['meta'].get('format_type', 'unknown')}"] += 1
        else:
            counts["other"] += 1

    counts["total"] = len(rows)
    counts["canonical_groups"] = len({r["canonical_id"] for r in rows})
    counts["contrastive_rows"] = sum(1 for r in rows if r["contrastive_ok"])
    return dict(counts)

def apply_train_oversampling(train_rows, cfg):
    weight = int(cfg.get("format_row_weight", 1))
    if weight <= 1:
        return train_rows

    out = list(train_rows)
    dup_idx = 0
    for r in train_rows:
        is_format = r["meta"].get("kind") == "format"
        is_role_confusion_view = bool(r["meta"].get("role_confusion_view"))
        is_generated_full_prompt = r["meta"].get("format_type") == "full_prompt"
        if not is_format or is_role_confusion_view or is_generated_full_prompt:
            continue
        for k in range(weight - 1):
            rr = deepcopy(r)
            dup_idx += 1
            rr["semantic_id"] = f"{rr['semantic_id']}|train_dup={dup_idx}"
            out.append(rr)
    return out

def write_json(path, obj):
    os.makedirs(os.path.dirname(path), exist_ok=True)
    with open(path, "w") as f:
        json.dump(obj, f, indent=2, sort_keys=True)

def append_jsonl(path, obj):
    os.makedirs(os.path.dirname(path), exist_ok=True)
    with open(path, "a") as f:
        f.write(json.dumps(obj, sort_keys=True) + "\n")

def save_rows_preview(rows, path, n=40):
    preview_rows = []
    for r in rows[:n]:
        preview_rows.append({
            "semantic_id": r["semantic_id"],
            "canonical_id": r["canonical_id"],
            "equiv_id": r["equiv_id"],
            "bucket_key": str(r["bucket_key"]),
            "text_en": r["text_en"],
            "text_py": r["text_py"],
            "meta": r["meta"],
        })
    write_json(path, preview_rows)

DUP_KEY = "canonical_id"

def row_key(r):
    return r[DUP_KEY]

def key_set(rows):
    return {row_key(r) for r in rows}

def overlap_keys(a_rows, b_rows):
    return key_set(a_rows) & key_set(b_rows)

def drop_train_overlaps(train_rows, val_rows):
    val_keys = key_set(val_rows)
    kept = [r for r in train_rows if row_key(r) not in val_keys]
    skipped = len(train_rows) - len(kept)
    print(f"[bridge] skipped train rows overlapping val by {DUP_KEY}: {skipped}")
    return kept, skipped

def split_overlap_count(train_rows, val_rows):
    return len(overlap_keys(train_rows, val_rows))

def debug_dup_key():
    x = expr_canonical_id(Bin("and", Atom("a"), Atom("b")))
    y = expr_canonical_id(Bin("and", Atom("b"), Atom("a")))
    print("[bridge] duplicate key:", DUP_KEY)
    print("[bridge] order-sensitive check and(a,b) != and(b,a):", x != y, "|", x, "|", y)

def train_one_variant(cfg):
    cfg = dict(cfg)
    cfg["data_seed"] = DATA_SEED
    cfg["split_seed"] = SPLIT_SEED
    cfg["train_seed"] = TRAIN_SEED_BASE + int(cfg["idx"])

    variant_dir = os.path.join(OUT_DIR, cfg["name"])
    best_dir = os.path.join(variant_dir, "best")
    last_dir = os.path.join(variant_dir, "last")
    summary_path = os.path.join(variant_dir, "summary.json")
    history_path = os.path.join(variant_dir, "metrics_history.jsonl")

    os.makedirs(variant_dir, exist_ok=True)
    if os.path.exists(history_path):
        os.remove(history_path)

    print("\n" + "=" * 90)
    print(f"START VARIANT {cfg['idx']}: {cfg['name']}")
    print("=" * 90)
    print(json.dumps(cfg, indent=2, sort_keys=True))
    write_json(os.path.join(variant_dir, "config.json"), cfg)

    set_seed(cfg["train_seed"])

    base_cfg = dict(cfg)
    base_cfg["full_prompt_rows"] = 0
    base_cfg["seed"] = DATA_SEED

    base_rows = build_rows(base_cfg)
    full_prompt_val_rows = build_full_prompt_val_rows()
    forced_val_ids = important_format_val_ids(base_rows)
    train_rows_raw, val_rows = split_rows(base_rows, seed=SPLIT_SEED, force_val_ids=forced_val_ids)
    val_rows = val_rows + full_prompt_val_rows

    base_split_overlap = overlap_keys(train_rows_raw, val_rows)

    print(f"[bridge] base train/val {DUP_KEY} overlap before skip: {len(base_split_overlap)}")
    train_rows_raw, base_skipped_train_overlap = drop_train_overlaps(train_rows_raw, val_rows)
    base_train_ids = key_set(train_rows_raw)
    base_val_ids = key_set(val_rows)

    extra_full_prompt_rows = []
    n_full = int(cfg.get("full_prompt_rows", 0))
    if n_full > 0:
        extra_full_prompt_rows = build_full_prompt_rows(n_full, seed=DATA_SEED)
        train_rows_raw = train_rows_raw + extra_full_prompt_rows

    rows = base_rows + full_prompt_val_rows + extra_full_prompt_rows

    role_confusion_rows = build_role_confusion_views(train_rows_raw) if USE_ROLE_CONFUSION_ROWS else []
    train_rows_raw_with_confusion = train_rows_raw + role_confusion_rows
    train_rows = apply_train_oversampling(train_rows_raw_with_confusion, cfg)

    train_rows, final_skipped_train_overlap = drop_train_overlaps(train_rows, val_rows)

    split_overlap = overlap_keys(train_rows, val_rows)
    train_ids = key_set(train_rows)
    val_ids = key_set(val_rows)

    print(f"[bridge] final train/val {DUP_KEY} overlap after skip: {len(split_overlap)}")
    assert not split_overlap

    print(
        f"base_rows={len(base_rows)} | train_raw={len(train_rows_raw)} | "
        f"extra_full_prompt_train_only={len(extra_full_prompt_rows)} | "
        f"role_confusion_views={len(role_confusion_rows)} | "
        f"train_after_confusion_and_oversample={len(train_rows)} | val={len(val_rows)} | "
        f"forced_format_val_ids={len(forced_val_ids)} | full_prompt_val={len(full_prompt_val_rows)}"
    )
    print("rows summary:", rows_summary(rows))
    print("train_raw summary:", rows_summary(train_rows_raw))
    print("train summary:", rows_summary(train_rows))
    print("val summary:", rows_summary(val_rows))

    save_rows_preview(rows, os.path.join(variant_dir, "rows_preview.json"), n=50)
    save_rows_preview(val_rows, os.path.join(variant_dir, "val_rows_preview.json"), n=80)
    save_rows_preview(role_confusion_rows, os.path.join(variant_dir, "role_confusion_rows_preview.json"), n=80)

    model, tok = make_model(pooling=cfg["pooling"])

    collator = PairCollator(tok)
    train_sampler = BucketSampler(train_rows, BATCH_SIZE, cfg["train_seed"])
    train_loader = DataLoader(PairDataset(train_rows), batch_sampler=train_sampler, collate_fn=collator)
    steps_per_epoch = sum(1 for _ in train_sampler)
    train_sampler.set_epoch(0)

    opt = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
    total_steps = math.ceil(steps_per_epoch / GRAD_ACCUM) * EPOCHS
    warmup_steps = int(WARMUP_RATIO * total_steps)
    sch = get_linear_schedule_with_warmup(opt, warmup_steps, total_steps)

    best_score = float("inf")
    best_metrics = None
    best_epoch = None
    start_time = time.time()

    for epoch in range(EPOCHS):
        train_sampler.set_epoch(epoch)
        model.train()
        opt.zero_grad(set_to_none=True)

        run_total = run_ce = run_ctr = run_w = 0.0
        run_n = 0

        for step, batch in enumerate(train_loader):
            z_en, z_py, ce = model(to_device(batch["en"], DEVICE), to_device(batch["py"], DEVICE))
            ctr, _, _, _ = contrastive_loss(
                z_en,
                z_py,
                batch["canonical_ids"],
                batch["equiv_ids"],
                batch["contrastive_ok"],
                temperature=float(cfg["temperature"]),
            )
            loss, weight = bridge_loss(
                ce,
                ctr,
                contrastive_lambda=CONTRASTIVE_LAMBDA,
                contrastive_scale=float(cfg["contrastive_scale"]),
            )
            (loss / GRAD_ACCUM).backward()

            if (step + 1) % GRAD_ACCUM == 0:
                torch.nn.utils.clip_grad_norm_(model.parameters(), MAX_GRAD_NORM)
                opt.step()
                sch.step()
                opt.zero_grad(set_to_none=True)

            bsz = len(batch["semantic_ids"])
            run_total += loss.item() * bsz
            run_ce += ce.item() * bsz
            run_ctr += ctr.item() * bsz
            run_w += weight.item() * bsz
            run_n += bsz

        metrics = eval_model(model, val_rows, tok)
        score = metrics["ce"]

        row = {
            "variant": cfg["name"],
            "epoch": epoch + 1,
            "train_total": run_total / run_n,
            "train_ce": run_ce / run_n,
            "train_ctr": run_ctr / run_n,
            "ctr_weight": run_w / run_n,
            **{f"val_{k}": v for k, v in metrics.items()},
        }
        append_jsonl(history_path, row)

        print(
            f"[{cfg['name']} epoch {epoch+1:03d}/{EPOCHS}] "
            f"train_total={row['train_total']:.4f} | "
            f"train_ce={row['train_ce']:.4f} | "
            f"train_ctr={row['train_ctr']:.4f} | "
            f"ctr_weight={row['ctr_weight']:.2f} | "
            f"val_top1_canon={metrics['top1_canonical']:.4f} | "
            f"val_pos={metrics['mean_pos_sim']:.4f} | "
            f"val_neg={metrics['mean_neg_sim']:.4f} | "
            f"val_ce={metrics['ce']:.4f}"
        )

        if score < best_score:
            best_score = score
            best_metrics = deepcopy(metrics)
            best_epoch = epoch + 1
            os.makedirs(best_dir, exist_ok=True)
            model.lm.save_pretrained(best_dir, safe_serialization=True)
            tok.save_pretrained(best_dir)
            print("saved best adapter by val_ce to:", best_dir)

    os.makedirs(last_dir, exist_ok=True)
    model.lm.save_pretrained(last_dir, safe_serialization=True)
    tok.save_pretrained(last_dir)

    elapsed_min = (time.time() - start_time) / 60.0
    summary = {
        "config": cfg,
        "variant_dir": variant_dir,
        "best_dir": best_dir,
        "last_dir": last_dir,
        "best_epoch": best_epoch,
        "best_score": best_score,
        "best_metrics": best_metrics,
        "rows_summary": rows_summary(rows),
        "train_raw_summary": rows_summary(train_rows_raw),
        "extra_full_prompt_train_only_summary": rows_summary(extra_full_prompt_rows),
        "role_confusion_summary": rows_summary(role_confusion_rows),
        "train_after_confusion_and_oversample_summary": rows_summary(train_rows),
        "val_summary": rows_summary(val_rows),
        "split_protection": {
            "unit": "canonical_id",
            "base_train_val_overlap_before_skip": len(base_split_overlap),
            "base_skipped_train_overlap": base_skipped_train_overlap,
            "final_skipped_train_overlap": final_skipped_train_overlap,
            "final_train_val_overlap_after_skip": len(split_overlap),
            "base_train_canonical_ids": len(base_train_ids),
            "base_val_canonical_ids": len(base_val_ids),
            "final_train_canonical_ids": len(train_ids),
            "final_val_canonical_ids": len(val_ids),
        },
        "selection_rule": "best adapter is selected by lowest validation ce",
        "forced_format_val_ids": len(forced_val_ids),
        "full_prompt_val_summary": rows_summary(full_prompt_val_rows),
        "elapsed_minutes": elapsed_min,
    }
    write_json(summary_path, summary)
    print("\nDONE:", cfg["name"])
    print("best_epoch:", best_epoch)
    print("best_metrics:", best_metrics)
    print("saved best adapter to:", best_dir)
    print("saved last adapter to:", last_dir)

    del model, tok, opt, sch, train_loader, train_sampler
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    return summary

def write_suite_summary(summaries):
    out_json = os.path.join(OUT_DIR, "summary_all.json")
    write_json(out_json, summaries)

    out_csv = os.path.join(OUT_DIR, "summary_all.csv")
    fields = [
        "idx", "name", "full_prompt_rows", "format_row_weight",
        "contrastive_scale", "temperature", "pooling",
        "best_epoch", "best_score", "top1_canonical",
        "mean_pos_sim", "mean_neg_sim", "ce",
        "best_dir", "last_dir",
    ]
    with open(out_csv, "w", newline="") as f:
        writer = csv.DictWriter(f, fieldnames=fields)
        writer.writeheader()
        for s in summaries:
            cfg = s.get("config", {})
            m = s.get("best_metrics") or {}
            writer.writerow({
                "idx": cfg.get("idx"),
                "name": cfg.get("name"),
                "full_prompt_rows": cfg.get("full_prompt_rows"),
                "format_row_weight": cfg.get("format_row_weight"),
                "contrastive_scale": cfg.get("contrastive_scale"),
                "temperature": cfg.get("temperature"),
                "pooling": cfg.get("pooling"),
                "best_epoch": s.get("best_epoch"),
                "best_score": s.get("best_score"),
                "top1_canonical": m.get("top1_canonical"),
                "mean_pos_sim": m.get("mean_pos_sim"),
                "mean_neg_sim": m.get("mean_neg_sim"),
                "ce": m.get("ce"),
                "best_dir": s.get("best_dir"),
                "last_dir": s.get("last_dir"),
            })

    print("\nSuite summary saved:")
    print(out_json)
    print(out_csv)

def train_suite():
    summaries = []
    selected = [v for v in RUNS if v["idx"] in RUN_IDS]

    debug_dup_key()

    for i, cfg in enumerate(selected):
        summaries.append(train_one_variant(cfg))
        write_suite_summary(summaries)

    return summaries

summaries = train_suite()
summaries
# Out:
# [bridge] duplicate key: canonical_id
# [bridge] order-sensitive check and(a,b) != and(b,a): True | surface|and(a,b) | surface|and(b,a)
#
# ==========================================================================================
# START VARIANT 0: baseline
# ==========================================================================================
# {
#   "contrastive_scale": 1.0,
#   "data_seed": 42,
#   "format_row_weight": 1,
#   "full_prompt_rows": 0,
#   "idx": 0,
#   "name": "baseline",
#   "pooling": "last",
#   "split_seed": 42,
#   "temperature": 0.05,
#   "train_seed": 42
# }
# [bridge] base train/val canonical_id overlap before skip: 0
# [bridge] skipped train rows overlapping val by canonical_id: 0
# [bridge] skipped train rows overlapping val by canonical_id: 0
# [bridge] final train/val canonical_id overlap after skip: 0
# base_rows=1046 | train_raw=883 | extra_full_prompt_train_only=0 | role_confusion_views=118 | train_after_confusion_and_oversample=1001 | val=166 | forced_format_val_ids=13 | full_prompt_val=3
# rows summary: {'expr': 200, 'rule': 800, 'format': 49, 'format_header': 3, 'format_return_condition': 4, 'format_return_block': 3, 'format_input_line': 8, 'format_input_block': 28, 'format_full_prompt_val': 3, 'total': 1049, 'canonical_groups': 1049, 'contrastive_rows': 1049}
# train_raw summary: {'expr': 171, 'rule': 679, 'format': 33, 'format_header': 2, 'format_return_condition': 2, 'format_return_block': 2, 'format_input_line': 4, 'format_input_block': 23, 'total': 883, 'canonical_groups': 883, 'contrastive_rows': 883}
# train summary: {'expr': 211, 'rule': 737, 'format': 53, 'format_header': 2, 'format_return_condition': 6, 'format_return_block': 2, 'format_input_line': 20, 'format_input_block': 23, 'role_confusion_views': 118, 'role_confusion_input_vs_atom': 6, 'role_confusion_input_vs_rule_atom': 26, 'role_confusion_expr_vs_rule_atom': 48, 'role_confusion_rule_atom_vs_return_condition': 9, 'role_confusion_iff_expr_vs_return_condition': 15, 'role_confusion_speaker_content_swap': 14, 'total': 1001, 'canonical_groups': 883, 'contrastive_rows': 1001}
# val summary: {'rule': 121, 'expr': 29, 'format': 16, 'format_header': 1, 'format_return_condition': 2, 'format_return_block': 1, 'format_input_line': 4, 'format_input_block': 5, 'format_full_prompt_val': 3, 'total': 166, 'canonical_groups': 166, 'contrastive_rows': 166}
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights:   0%|          | 0/292 [00:00<?, ?it/s]
# trainable params: 50,331,648 || all params: 1,464,979,456 || trainable%: 3.4357
# [baseline epoch 001/15] train_total=4.4499 | train_ce=2.2846 | train_ctr=1.1075 | ctr_weight=130.03 | val_top1_canon=0.8795 | val_pos=0.7803 | val_neg=0.1261 | val_ce=1.4411
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/baseline/best
# [baseline epoch 002/15] train_total=2.1879 | train_ce=1.3823 | train_ctr=0.0197 | ctr_weight=756.07 | val_top1_canon=0.8193 | val_pos=0.6362 | val_neg=0.0282 | val_ce=1.3011
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/baseline/best
# [baseline epoch 003/15] train_total=1.3747 | train_ce=1.0668 | train_ctr=0.0081 | ctr_weight=898.43 | val_top1_canon=0.8012 | val_pos=0.5532 | val_neg=0.0060 | val_ce=1.0686
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/baseline/best
# [baseline epoch 004/15] train_total=1.2597 | train_ce=0.9704 | train_ctr=0.0052 | ctr_weight=861.35 | val_top1_canon=0.8012 | val_pos=0.5742 | val_neg=0.0020 | val_ce=1.0285
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/baseline/best
# [baseline epoch 005/15] train_total=1.1217 | train_ce=0.9025 | train_ctr=0.0046 | ctr_weight=924.28 | val_top1_canon=0.7349 | val_pos=0.5034 | val_neg=-0.0505 | val_ce=0.9693
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/baseline/best
# [baseline epoch 006/15] train_total=1.2772 | train_ce=0.8997 | train_ctr=0.0042 | ctr_weight=859.87 | val_top1_canon=0.6566 | val_pos=0.4028 | val_neg=-0.1412 | val_ce=0.9313
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/baseline/best
# [baseline epoch 007/15] train_total=1.3403 | train_ce=0.8708 | train_ctr=0.0092 | ctr_weight=798.97 | val_top1_canon=0.6386 | val_pos=0.2878 | val_neg=-0.2384 | val_ce=0.9090
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/baseline/best
# [baseline epoch 008/15] train_total=1.2871 | train_ce=0.8596 | train_ctr=0.0057 | ctr_weight=835.31 | val_top1_canon=0.6084 | val_pos=0.2644 | val_neg=-0.2773 | val_ce=0.9685
# [baseline epoch 009/15] train_total=1.2563 | train_ce=0.8386 | train_ctr=0.0037 | ctr_weight=892.62 | val_top1_canon=0.5060 | val_pos=0.1616 | val_neg=-0.3418 | val_ce=0.9148
# [baseline epoch 010/15] train_total=1.2080 | train_ce=0.8303 | train_ctr=0.0172 | ctr_weight=884.04 | val_top1_canon=0.4639 | val_pos=0.1832 | val_neg=-0.3396 | val_ce=0.9137
# [baseline epoch 011/15] train_total=1.1150 | train_ce=0.8240 | train_ctr=0.0081 | ctr_weight=930.68 | val_top1_canon=0.5301 | val_pos=0.2009 | val_neg=-0.3396 | val_ce=0.9151
# [baseline epoch 012/15] train_total=1.1175 | train_ce=0.8224 | train_ctr=0.0066 | ctr_weight=929.06 | val_top1_canon=0.4277 | val_pos=0.1637 | val_neg=-0.3618 | val_ce=0.8875
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/baseline/best
# [baseline epoch 013/15] train_total=1.0682 | train_ce=0.8041 | train_ctr=0.0032 | ctr_weight=945.85 | val_top1_canon=0.2771 | val_pos=0.0980 | val_neg=-0.3977 | val_ce=0.8848
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/baseline/best
# [baseline epoch 014/15] train_total=1.0721 | train_ce=0.7998 | train_ctr=0.0033 | ctr_weight=937.41 | val_top1_canon=0.1988 | val_pos=0.0881 | val_neg=-0.4055 | val_ce=0.8762
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/baseline/best
# [baseline epoch 015/15] train_total=1.0633 | train_ce=0.7934 | train_ctr=0.0031 | ctr_weight=933.45 | val_top1_canon=0.1747 | val_pos=0.0784 | val_neg=-0.4111 | val_ce=0.8730
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/baseline/best
#
# DONE: baseline
# best_epoch: 15
# best_metrics: {'top1_canonical': 0.1746987951807229, 'mean_pos_sim': 0.078369140625, 'mean_neg_sim': -0.4111328125, 'ce': 0.8730195344212544, 'contrastive_rows': 166, 'ce_only_rows': 0}
# saved best adapter to: /content/drive/MyDrive/Test/Python/test_bridge_simple/baseline/best
# saved last adapter to: /content/drive/MyDrive/Test/Python/test_bridge_simple/baseline/last
#
# Suite summary saved:
# /content/drive/MyDrive/Test/Python/test_bridge_simple/summary_all.json
# /content/drive/MyDrive/Test/Python/test_bridge_simple/summary_all.csv
#
# ==========================================================================================
# START VARIANT 1: full_prompts_50
# ==========================================================================================
# {
#   "contrastive_scale": 1.0,
#   "data_seed": 42,
#   "format_row_weight": 1,
#   "full_prompt_rows": 50,
#   "idx": 1,
#   "name": "full_prompts_50",
#   "pooling": "last",
#   "split_seed": 42,
#   "temperature": 0.05,
#   "train_seed": 43
# }
# [bridge] base train/val canonical_id overlap before skip: 0
# [bridge] skipped train rows overlapping val by canonical_id: 0
# [bridge] skipped train rows overlapping val by canonical_id: 0
# [bridge] final train/val canonical_id overlap after skip: 0
# base_rows=1046 | train_raw=933 | extra_full_prompt_train_only=50 | role_confusion_views=118 | train_after_confusion_and_oversample=1051 | val=166 | forced_format_val_ids=13 | full_prompt_val=3
# rows summary: {'expr': 200, 'rule': 800, 'format': 99, 'format_header': 3, 'format_return_condition': 4, 'format_return_block': 3, 'format_input_line': 8, 'format_input_block': 28, 'format_full_prompt_val': 3, 'format_full_prompt': 50, 'total': 1099, 'canonical_groups': 1099, 'contrastive_rows': 1099}
# train_raw summary: {'expr': 171, 'rule': 679, 'format': 83, 'format_header': 2, 'format_return_condition': 2, 'format_return_block': 2, 'format_input_line': 4, 'format_input_block': 23, 'format_full_prompt': 50, 'total': 933, 'canonical_groups': 933, 'contrastive_rows': 933}
# train summary: {'expr': 211, 'rule': 737, 'format': 103, 'format_header': 2, 'format_return_condition': 6, 'format_return_block': 2, 'format_input_line': 20, 'format_input_block': 23, 'format_full_prompt': 50, 'role_confusion_views': 118, 'role_confusion_input_vs_atom': 6, 'role_confusion_input_vs_rule_atom': 26, 'role_confusion_expr_vs_rule_atom': 48, 'role_confusion_rule_atom_vs_return_condition': 9, 'role_confusion_iff_expr_vs_return_condition': 15, 'role_confusion_speaker_content_swap': 14, 'total': 1051, 'canonical_groups': 933, 'contrastive_rows': 1051}
# val summary: {'rule': 121, 'expr': 29, 'format': 16, 'format_header': 1, 'format_return_condition': 2, 'format_return_block': 1, 'format_input_line': 4, 'format_input_block': 5, 'format_full_prompt_val': 3, 'total': 166, 'canonical_groups': 166, 'contrastive_rows': 166}
# Loading weights:   0%|          | 0/292 [00:00<?, ?it/s]
# trainable params: 50,331,648 || all params: 1,464,979,456 || trainable%: 3.4357
# [full_prompts_50 epoch 001/15] train_total=4.5385 | train_ce=2.3181 | train_ctr=1.2044 | ctr_weight=83.62 | val_top1_canon=0.9036 | val_pos=0.8071 | val_neg=0.1283 | val_ce=1.7110
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/full_prompts_50/best
# [full_prompts_50 epoch 002/15] train_total=2.1135 | train_ce=1.4184 | train_ctr=0.1154 | ctr_weight=795.79 | val_top1_canon=0.8976 | val_pos=0.6543 | val_neg=0.0301 | val_ce=1.1531
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/full_prompts_50/best
# [full_prompts_50 epoch 003/15] train_total=1.4783 | train_ce=1.0775 | train_ctr=0.0533 | ctr_weight=814.62 | val_top1_canon=0.8434 | val_pos=0.5898 | val_neg=0.0160 | val_ce=0.9896
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/full_prompts_50/best
# [full_prompts_50 epoch 004/15] train_total=1.2159 | train_ce=0.9647 | train_ctr=0.0394 | ctr_weight=868.72 | val_top1_canon=0.8133 | val_pos=0.5498 | val_neg=-0.0014 | val_ce=0.9634
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/full_prompts_50/best
# [full_prompts_50 epoch 005/15] train_total=1.1949 | train_ce=0.9233 | train_ctr=0.0212 | ctr_weight=877.19 | val_top1_canon=0.8193 | val_pos=0.5732 | val_neg=-0.0154 | val_ce=0.9468
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/full_prompts_50/best
# [full_prompts_50 epoch 006/15] train_total=1.1573 | train_ce=0.8762 | train_ctr=0.0303 | ctr_weight=832.22 | val_top1_canon=0.7590 | val_pos=0.4692 | val_neg=-0.0723 | val_ce=0.9082
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/full_prompts_50/best
# [full_prompts_50 epoch 007/15] train_total=1.2570 | train_ce=0.8681 | train_ctr=0.0146 | ctr_weight=767.98 | val_top1_canon=0.6928 | val_pos=0.3086 | val_neg=-0.1726 | val_ce=0.9107
# [full_prompts_50 epoch 008/15] train_total=1.3628 | train_ce=0.8689 | train_ctr=0.0126 | ctr_weight=763.62 | val_top1_canon=0.7289 | val_pos=0.3381 | val_neg=-0.2087 | val_ce=0.8940
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/full_prompts_50/best
# [full_prompts_50 epoch 009/15] train_total=1.4003 | train_ce=0.8898 | train_ctr=0.0084 | ctr_weight=800.22 | val_top1_canon=0.6325 | val_pos=0.2632 | val_neg=-0.2644 | val_ce=0.9055
# [full_prompts_50 epoch 010/15] train_total=1.2680 | train_ce=0.8560 | train_ctr=0.0090 | ctr_weight=838.27 | val_top1_canon=0.5361 | val_pos=0.1698 | val_neg=-0.3240 | val_ce=0.9061
# [full_prompts_50 epoch 011/15] train_total=1.2744 | train_ce=0.8444 | train_ctr=0.0105 | ctr_weight=829.83 | val_top1_canon=0.4518 | val_pos=0.1560 | val_neg=-0.3425 | val_ce=0.8842
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/full_prompts_50/best
# [full_prompts_50 epoch 012/15] train_total=1.1877 | train_ce=0.8248 | train_ctr=0.0141 | ctr_weight=882.93 | val_top1_canon=0.3494 | val_pos=0.1229 | val_neg=-0.3640 | val_ce=0.8555
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/full_prompts_50/best
# [full_prompts_50 epoch 013/15] train_total=1.1645 | train_ce=0.8137 | train_ctr=0.0159 | ctr_weight=884.20 | val_top1_canon=0.4699 | val_pos=0.1426 | val_neg=-0.3599 | val_ce=0.8546
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/full_prompts_50/best
# [full_prompts_50 epoch 014/15] train_total=1.1416 | train_ce=0.8083 | train_ctr=0.0098 | ctr_weight=887.16 | val_top1_canon=0.2952 | val_pos=0.0991 | val_neg=-0.3835 | val_ce=0.8471
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/full_prompts_50/best
# [full_prompts_50 epoch 015/15] train_total=1.0961 | train_ce=0.8015 | train_ctr=0.0108 | ctr_weight=904.10 | val_top1_canon=0.3494 | val_pos=0.1038 | val_neg=-0.3826 | val_ce=0.8468
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/full_prompts_50/best
#
# DONE: full_prompts_50
# best_epoch: 15
# best_metrics: {'top1_canonical': 0.3493975903614458, 'mean_pos_sim': 0.10382080078125, 'mean_neg_sim': -0.382568359375, 'ce': 0.8468386839671307, 'contrastive_rows': 166, 'ce_only_rows': 0}
# saved best adapter to: /content/drive/MyDrive/Test/Python/test_bridge_simple/full_prompts_50/best
# saved last adapter to: /content/drive/MyDrive/Test/Python/test_bridge_simple/full_prompts_50/last
#
# Suite summary saved:
# /content/drive/MyDrive/Test/Python/test_bridge_simple/summary_all.json
# /content/drive/MyDrive/Test/Python/test_bridge_simple/summary_all.csv
#
# ==========================================================================================
# START VARIANT 3: format_2x
# ==========================================================================================
# {
#   "contrastive_scale": 1.0,
#   "data_seed": 42,
#   "format_row_weight": 2,
#   "full_prompt_rows": 0,
#   "idx": 3,
#   "name": "format_2x",
#   "pooling": "last",
#   "split_seed": 42,
#   "temperature": 0.05,
#   "train_seed": 45
# }
# [bridge] base train/val canonical_id overlap before skip: 0
# [bridge] skipped train rows overlapping val by canonical_id: 0
# [bridge] skipped train rows overlapping val by canonical_id: 0
# [bridge] final train/val canonical_id overlap after skip: 0
# base_rows=1046 | train_raw=883 | extra_full_prompt_train_only=0 | role_confusion_views=118 | train_after_confusion_and_oversample=1034 | val=166 | forced_format_val_ids=13 | full_prompt_val=3
# rows summary: {'expr': 200, 'rule': 800, 'format': 49, 'format_header': 3, 'format_return_condition': 4, 'format_return_block': 3, 'format_input_line': 8, 'format_input_block': 28, 'format_full_prompt_val': 3, 'total': 1049, 'canonical_groups': 1049, 'contrastive_rows': 1049}
# train_raw summary: {'expr': 171, 'rule': 679, 'format': 33, 'format_header': 2, 'format_return_condition': 2, 'format_return_block': 2, 'format_input_line': 4, 'format_input_block': 23, 'total': 883, 'canonical_groups': 883, 'contrastive_rows': 883}
# train summary: {'expr': 211, 'rule': 737, 'format': 86, 'format_header': 4, 'format_return_condition': 8, 'format_return_block': 4, 'format_input_line': 24, 'format_input_block': 46, 'role_confusion_views': 118, 'role_confusion_input_vs_atom': 6, 'role_confusion_input_vs_rule_atom': 26, 'role_confusion_expr_vs_rule_atom': 48, 'role_confusion_rule_atom_vs_return_condition': 9, 'role_confusion_iff_expr_vs_return_condition': 15, 'role_confusion_speaker_content_swap': 14, 'total': 1034, 'canonical_groups': 883, 'contrastive_rows': 1034}
# val summary: {'rule': 121, 'expr': 29, 'format': 16, 'format_header': 1, 'format_return_condition': 2, 'format_return_block': 1, 'format_input_line': 4, 'format_input_block': 5, 'format_full_prompt_val': 3, 'total': 166, 'canonical_groups': 166, 'contrastive_rows': 166}
# Loading weights:   0%|          | 0/292 [00:00<?, ?it/s]
# trainable params: 50,331,648 || all params: 1,464,979,456 || trainable%: 3.4357
# [format_2x epoch 001/15] train_total=4.5732 | train_ce=2.3441 | train_ctr=1.1818 | ctr_weight=81.94 | val_top1_canon=0.9337 | val_pos=0.7563 | val_neg=0.1270 | val_ce=1.4691
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/format_2x/best
# [format_2x epoch 002/15] train_total=2.1255 | train_ce=1.3684 | train_ctr=0.0401 | ctr_weight=714.21 | val_top1_canon=0.8554 | val_pos=0.6445 | val_neg=0.0335 | val_ce=1.2388
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/format_2x/best
# [format_2x epoch 003/15] train_total=1.4549 | train_ce=1.0704 | train_ctr=0.0121 | ctr_weight=838.58 | val_top1_canon=0.8554 | val_pos=0.6128 | val_neg=0.0182 | val_ce=1.0070
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/format_2x/best
# [format_2x epoch 004/15] train_total=1.1543 | train_ce=0.9206 | train_ctr=0.0072 | ctr_weight=901.45 | val_top1_canon=0.8795 | val_pos=0.6187 | val_neg=0.0061 | val_ce=0.9970
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/format_2x/best
# [format_2x epoch 005/15] train_total=1.1125 | train_ce=0.8818 | train_ctr=0.0070 | ctr_weight=914.79 | val_top1_canon=0.8012 | val_pos=0.5674 | val_neg=-0.0080 | val_ce=0.8759
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/format_2x/best
# [format_2x epoch 006/15] train_total=1.0893 | train_ce=0.8545 | train_ctr=0.0041 | ctr_weight=889.31 | val_top1_canon=0.8012 | val_pos=0.5527 | val_neg=-0.0346 | val_ce=0.8694
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/format_2x/best
# [format_2x epoch 007/15] train_total=1.1648 | train_ce=0.8332 | train_ctr=0.0040 | ctr_weight=877.76 | val_top1_canon=0.7048 | val_pos=0.4565 | val_neg=-0.1077 | val_ce=0.9093
# [format_2x epoch 008/15] train_total=1.2765 | train_ce=0.8335 | train_ctr=0.0059 | ctr_weight=797.49 | val_top1_canon=0.5904 | val_pos=0.2698 | val_neg=-0.2252 | val_ce=0.9395
# [format_2x epoch 009/15] train_total=1.2936 | train_ce=0.8282 | train_ctr=0.0110 | ctr_weight=793.30 | val_top1_canon=0.6205 | val_pos=0.2542 | val_neg=-0.2588 | val_ce=0.9273
# [format_2x epoch 010/15] train_total=1.2761 | train_ce=0.8380 | train_ctr=0.0057 | ctr_weight=851.42 | val_top1_canon=0.3554 | val_pos=0.1278 | val_neg=-0.3345 | val_ce=0.8857
# [format_2x epoch 011/15] train_total=1.2072 | train_ce=0.8233 | train_ctr=0.0146 | ctr_weight=892.69 | val_top1_canon=0.5482 | val_pos=0.1930 | val_neg=-0.3152 | val_ce=0.9152
# [format_2x epoch 012/15] train_total=1.1417 | train_ce=0.8163 | train_ctr=0.0078 | ctr_weight=924.44 | val_top1_canon=0.5723 | val_pos=0.2034 | val_neg=-0.3140 | val_ce=0.8967
# [format_2x epoch 013/15] train_total=1.0824 | train_ce=0.8066 | train_ctr=0.0041 | ctr_weight=953.67 | val_top1_canon=0.5301 | val_pos=0.1912 | val_neg=-0.3267 | val_ce=0.8992
# [format_2x epoch 014/15] train_total=1.1080 | train_ce=0.7993 | train_ctr=0.0038 | ctr_weight=951.05 | val_top1_canon=0.5181 | val_pos=0.1437 | val_neg=-0.3516 | val_ce=0.8996
# [format_2x epoch 015/15] train_total=1.0563 | train_ce=0.7950 | train_ctr=0.0034 | ctr_weight=970.05 | val_top1_canon=0.4940 | val_pos=0.1240 | val_neg=-0.3618 | val_ce=0.8981
#
# DONE: format_2x
# best_epoch: 6
# best_metrics: {'top1_canonical': 0.8012048192771084, 'mean_pos_sim': 0.552734375, 'mean_neg_sim': -0.034637451171875, 'ce': 0.8693843448018453, 'contrastive_rows': 166, 'ce_only_rows': 0}
# saved best adapter to: /content/drive/MyDrive/Test/Python/test_bridge_simple/format_2x/best
# saved last adapter to: /content/drive/MyDrive/Test/Python/test_bridge_simple/format_2x/last
#
# Suite summary saved:
# /content/drive/MyDrive/Test/Python/test_bridge_simple/summary_all.json
# /content/drive/MyDrive/Test/Python/test_bridge_simple/summary_all.csv
#
# ==========================================================================================
# START VARIANT 4: full_prompts_50_format_2x
# ==========================================================================================
# {
#   "contrastive_scale": 1.0,
#   "data_seed": 42,
#   "format_row_weight": 2,
#   "full_prompt_rows": 50,
#   "idx": 4,
#   "name": "full_prompts_50_format_2x",
#   "pooling": "last",
#   "split_seed": 42,
#   "temperature": 0.05,
#   "train_seed": 46
# }
# [bridge] base train/val canonical_id overlap before skip: 0
# [bridge] skipped train rows overlapping val by canonical_id: 0
# [bridge] skipped train rows overlapping val by canonical_id: 0
# [bridge] final train/val canonical_id overlap after skip: 0
# base_rows=1046 | train_raw=933 | extra_full_prompt_train_only=50 | role_confusion_views=118 | train_after_confusion_and_oversample=1084 | val=166 | forced_format_val_ids=13 | full_prompt_val=3
# rows summary: {'expr': 200, 'rule': 800, 'format': 99, 'format_header': 3, 'format_return_condition': 4, 'format_return_block': 3, 'format_input_line': 8, 'format_input_block': 28, 'format_full_prompt_val': 3, 'format_full_prompt': 50, 'total': 1099, 'canonical_groups': 1099, 'contrastive_rows': 1099}
# train_raw summary: {'expr': 171, 'rule': 679, 'format': 83, 'format_header': 2, 'format_return_condition': 2, 'format_return_block': 2, 'format_input_line': 4, 'format_input_block': 23, 'format_full_prompt': 50, 'total': 933, 'canonical_groups': 933, 'contrastive_rows': 933}
# train summary: {'expr': 211, 'rule': 737, 'format': 136, 'format_header': 4, 'format_return_condition': 8, 'format_return_block': 4, 'format_input_line': 24, 'format_input_block': 46, 'format_full_prompt': 50, 'role_confusion_views': 118, 'role_confusion_input_vs_atom': 6, 'role_confusion_input_vs_rule_atom': 26, 'role_confusion_expr_vs_rule_atom': 48, 'role_confusion_rule_atom_vs_return_condition': 9, 'role_confusion_iff_expr_vs_return_condition': 15, 'role_confusion_speaker_content_swap': 14, 'total': 1084, 'canonical_groups': 933, 'contrastive_rows': 1084}
# val summary: {'rule': 121, 'expr': 29, 'format': 16, 'format_header': 1, 'format_return_condition': 2, 'format_return_block': 1, 'format_input_line': 4, 'format_input_block': 5, 'format_full_prompt_val': 3, 'total': 166, 'canonical_groups': 166, 'contrastive_rows': 166}
# Loading weights:   0%|          | 0/292 [00:00<?, ?it/s]
# trainable params: 50,331,648 || all params: 1,464,979,456 || trainable%: 3.4357
# [full_prompts_50_format_2x epoch 001/15] train_total=4.4292 | train_ce=2.2940 | train_ctr=1.2127 | ctr_weight=117.81 | val_top1_canon=0.8614 | val_pos=0.7363 | val_neg=0.1083 | val_ce=1.3401
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/full_prompts_50_format_2x/best
# [full_prompts_50_format_2x epoch 002/15] train_total=2.1072 | train_ce=1.3166 | train_ctr=0.1156 | ctr_weight=671.86 | val_top1_canon=0.8554 | val_pos=0.6118 | val_neg=0.0252 | val_ce=1.3388
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/full_prompts_50_format_2x/best
# [full_prompts_50_format_2x epoch 003/15] train_total=1.5308 | train_ce=1.1132 | train_ctr=0.0651 | ctr_weight=846.56 | val_top1_canon=0.8373 | val_pos=0.5752 | val_neg=0.0123 | val_ce=1.0288
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/full_prompts_50_format_2x/best
# [full_prompts_50_format_2x epoch 004/15] train_total=1.2136 | train_ce=0.9501 | train_ctr=0.0329 | ctr_weight=860.46 | val_top1_canon=0.8072 | val_pos=0.5898 | val_neg=0.0012 | val_ce=0.8987
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/full_prompts_50_format_2x/best
# [full_prompts_50_format_2x epoch 005/15] train_total=1.1973 | train_ce=0.8916 | train_ctr=0.0151 | ctr_weight=863.19 | val_top1_canon=0.7711 | val_pos=0.5913 | val_neg=-0.0096 | val_ce=0.8752
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/full_prompts_50_format_2x/best
# [full_prompts_50_format_2x epoch 006/15] train_total=1.1194 | train_ce=0.8683 | train_ctr=0.0117 | ctr_weight=873.32 | val_top1_canon=0.7410 | val_pos=0.5264 | val_neg=-0.0458 | val_ce=0.9157
# [full_prompts_50_format_2x epoch 007/15] train_total=1.2140 | train_ce=0.8589 | train_ctr=0.0131 | ctr_weight=828.67 | val_top1_canon=0.7048 | val_pos=0.4758 | val_neg=-0.1027 | val_ce=0.8801
# [full_prompts_50_format_2x epoch 008/15] train_total=1.2799 | train_ce=0.8396 | train_ctr=0.0093 | ctr_weight=761.40 | val_top1_canon=0.6566 | val_pos=0.2625 | val_neg=-0.2333 | val_ce=0.8985
# [full_prompts_50_format_2x epoch 009/15] train_total=1.3117 | train_ce=0.8353 | train_ctr=0.0083 | ctr_weight=782.05 | val_top1_canon=0.5964 | val_pos=0.2191 | val_neg=-0.2793 | val_ce=0.8884
# [full_prompts_50_format_2x epoch 010/15] train_total=1.2807 | train_ce=0.8395 | train_ctr=0.0062 | ctr_weight=800.22 | val_top1_canon=0.5181 | val_pos=0.1945 | val_neg=-0.3044 | val_ce=0.8830
# [full_prompts_50_format_2x epoch 011/15] train_total=1.2490 | train_ce=0.8306 | train_ctr=0.0042 | ctr_weight=842.52 | val_top1_canon=0.5663 | val_pos=0.1702 | val_neg=-0.3301 | val_ce=0.8830
# [full_prompts_50_format_2x epoch 012/15] train_total=1.2234 | train_ce=0.8251 | train_ctr=0.0118 | ctr_weight=887.06 | val_top1_canon=0.5120 | val_pos=0.1427 | val_neg=-0.3496 | val_ce=0.8704
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/full_prompts_50_format_2x/best
# [full_prompts_50_format_2x epoch 013/15] train_total=1.1533 | train_ce=0.8012 | train_ctr=0.0085 | ctr_weight=875.97 | val_top1_canon=0.5361 | val_pos=0.1641 | val_neg=-0.3459 | val_ce=0.8666
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/full_prompts_50_format_2x/best
# [full_prompts_50_format_2x epoch 014/15] train_total=1.1143 | train_ce=0.7967 | train_ctr=0.0148 | ctr_weight=901.54 | val_top1_canon=0.2651 | val_pos=0.1156 | val_neg=-0.3713 | val_ce=0.8608
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/full_prompts_50_format_2x/best
# [full_prompts_50_format_2x epoch 015/15] train_total=1.1036 | train_ce=0.7912 | train_ctr=0.0153 | ctr_weight=909.73 | val_top1_canon=0.2831 | val_pos=0.1215 | val_neg=-0.3701 | val_ce=0.8568
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/full_prompts_50_format_2x/best
#
# DONE: full_prompts_50_format_2x
# best_epoch: 15
# best_metrics: {'top1_canonical': 0.28313253012048195, 'mean_pos_sim': 0.1214599609375, 'mean_neg_sim': -0.3701171875, 'ce': 0.8567972463297556, 'contrastive_rows': 166, 'ce_only_rows': 0}
# saved best adapter to: /content/drive/MyDrive/Test/Python/test_bridge_simple/full_prompts_50_format_2x/best
# saved last adapter to: /content/drive/MyDrive/Test/Python/test_bridge_simple/full_prompts_50_format_2x/last
#
# Suite summary saved:
# /content/drive/MyDrive/Test/Python/test_bridge_simple/summary_all.json
# /content/drive/MyDrive/Test/Python/test_bridge_simple/summary_all.csv
#
# ==========================================================================================
# START VARIANT 5: contrastive_0p5x
# ==========================================================================================
# {
#   "contrastive_scale": 0.5,
#   "data_seed": 42,
#   "format_row_weight": 1,
#   "full_prompt_rows": 0,
#   "idx": 5,
#   "name": "contrastive_0p5x",
#   "pooling": "last",
#   "split_seed": 42,
#   "temperature": 0.05,
#   "train_seed": 47
# }
# [bridge] base train/val canonical_id overlap before skip: 0
# [bridge] skipped train rows overlapping val by canonical_id: 0
# [bridge] skipped train rows overlapping val by canonical_id: 0
# [bridge] final train/val canonical_id overlap after skip: 0
# base_rows=1046 | train_raw=883 | extra_full_prompt_train_only=0 | role_confusion_views=118 | train_after_confusion_and_oversample=1001 | val=166 | forced_format_val_ids=13 | full_prompt_val=3
# rows summary: {'expr': 200, 'rule': 800, 'format': 49, 'format_header': 3, 'format_return_condition': 4, 'format_return_block': 3, 'format_input_line': 8, 'format_input_block': 28, 'format_full_prompt_val': 3, 'total': 1049, 'canonical_groups': 1049, 'contrastive_rows': 1049}
# train_raw summary: {'expr': 171, 'rule': 679, 'format': 33, 'format_header': 2, 'format_return_condition': 2, 'format_return_block': 2, 'format_input_line': 4, 'format_input_block': 23, 'total': 883, 'canonical_groups': 883, 'contrastive_rows': 883}
# train summary: {'expr': 211, 'rule': 737, 'format': 53, 'format_header': 2, 'format_return_condition': 6, 'format_return_block': 2, 'format_input_line': 20, 'format_input_block': 23, 'role_confusion_views': 118, 'role_confusion_input_vs_atom': 6, 'role_confusion_input_vs_rule_atom': 26, 'role_confusion_expr_vs_rule_atom': 48, 'role_confusion_rule_atom_vs_return_condition': 9, 'role_confusion_iff_expr_vs_return_condition': 15, 'role_confusion_speaker_content_swap': 14, 'total': 1001, 'canonical_groups': 883, 'contrastive_rows': 1001}
# val summary: {'rule': 121, 'expr': 29, 'format': 16, 'format_header': 1, 'format_return_condition': 2, 'format_return_block': 1, 'format_input_line': 4, 'format_input_block': 5, 'format_full_prompt_val': 3, 'total': 166, 'canonical_groups': 166, 'contrastive_rows': 166}
# Loading weights:   0%|          | 0/292 [00:00<?, ?it/s]
# trainable params: 50,331,648 || all params: 1,464,979,456 || trainable%: 3.4357
# [contrastive_0p5x epoch 001/15] train_total=3.1825 | train_ce=2.1566 | train_ctr=1.2765 | ctr_weight=42.49 | val_top1_canon=0.8735 | val_pos=0.7710 | val_neg=0.1608 | val_ce=1.1550
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/contrastive_0p5x/best
# [contrastive_0p5x epoch 002/15] train_total=1.4721 | train_ce=1.1442 | train_ctr=0.0292 | ctr_weight=347.57 | val_top1_canon=0.8735 | val_pos=0.6318 | val_neg=0.0323 | val_ce=1.2415
# [contrastive_0p5x epoch 003/15] train_total=1.1137 | train_ce=0.9797 | train_ctr=0.0081 | ctr_weight=452.19 | val_top1_canon=0.8193 | val_pos=0.5596 | val_neg=0.0121 | val_ce=0.9771
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/contrastive_0p5x/best
# [contrastive_0p5x epoch 004/15] train_total=0.9646 | train_ce=0.8712 | train_ctr=0.0035 | ctr_weight=450.78 | val_top1_canon=0.8012 | val_pos=0.5942 | val_neg=0.0053 | val_ce=0.8830
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/contrastive_0p5x/best
# [contrastive_0p5x epoch 005/15] train_total=0.9213 | train_ce=0.8507 | train_ctr=0.0022 | ctr_weight=459.77 | val_top1_canon=0.7530 | val_pos=0.5596 | val_neg=-0.0177 | val_ce=0.8561
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/contrastive_0p5x/best
# [contrastive_0p5x epoch 006/15] train_total=0.9679 | train_ce=0.8359 | train_ctr=0.0027 | ctr_weight=436.46 | val_top1_canon=0.6928 | val_pos=0.4465 | val_neg=-0.0967 | val_ce=0.8979
# [contrastive_0p5x epoch 007/15] train_total=1.0063 | train_ce=0.8241 | train_ctr=0.0025 | ctr_weight=418.68 | val_top1_canon=0.6627 | val_pos=0.4207 | val_neg=-0.1445 | val_ce=0.8716
# [contrastive_0p5x epoch 008/15] train_total=1.0357 | train_ce=0.8141 | train_ctr=0.0033 | ctr_weight=381.91 | val_top1_canon=0.6386 | val_pos=0.3376 | val_neg=-0.2198 | val_ce=0.9328
# [contrastive_0p5x epoch 009/15] train_total=1.0116 | train_ce=0.8204 | train_ctr=0.0026 | ctr_weight=433.38 | val_top1_canon=0.6627 | val_pos=0.1486 | val_neg=-0.3218 | val_ce=0.8815
# [contrastive_0p5x epoch 010/15] train_total=0.9973 | train_ce=0.8073 | train_ctr=0.0028 | ctr_weight=447.69 | val_top1_canon=0.5783 | val_pos=0.1865 | val_neg=-0.3169 | val_ce=0.8866
# [contrastive_0p5x epoch 011/15] train_total=0.9792 | train_ce=0.8103 | train_ctr=0.0062 | ctr_weight=462.56 | val_top1_canon=0.5964 | val_pos=0.1633 | val_neg=-0.3389 | val_ce=0.8702
# [contrastive_0p5x epoch 012/15] train_total=0.9481 | train_ce=0.7882 | train_ctr=0.0041 | ctr_weight=448.72 | val_top1_canon=0.5783 | val_pos=0.1337 | val_neg=-0.3618 | val_ce=0.8567
# [contrastive_0p5x epoch 013/15] train_total=0.9075 | train_ce=0.7860 | train_ctr=0.0052 | ctr_weight=461.45 | val_top1_canon=0.5843 | val_pos=0.1329 | val_neg=-0.3672 | val_ce=0.8561
# [contrastive_0p5x epoch 014/15] train_total=0.9090 | train_ce=0.7846 | train_ctr=0.0029 | ctr_weight=470.38 | val_top1_canon=0.5783 | val_pos=0.1190 | val_neg=-0.3752 | val_ce=0.8525
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/contrastive_0p5x/best
# [contrastive_0p5x epoch 015/15] train_total=0.9082 | train_ce=0.7790 | train_ctr=0.0022 | ctr_weight=476.06 | val_top1_canon=0.5663 | val_pos=0.1244 | val_neg=-0.3748 | val_ce=0.8543
#
# DONE: contrastive_0p5x
# best_epoch: 14
# best_metrics: {'top1_canonical': 0.5783132530120482, 'mean_pos_sim': 0.1190185546875, 'mean_neg_sim': -0.375244140625, 'ce': 0.8524519707783159, 'contrastive_rows': 166, 'ce_only_rows': 0}
# saved best adapter to: /content/drive/MyDrive/Test/Python/test_bridge_simple/contrastive_0p5x/best
# saved last adapter to: /content/drive/MyDrive/Test/Python/test_bridge_simple/contrastive_0p5x/last
#
# Suite summary saved:
# /content/drive/MyDrive/Test/Python/test_bridge_simple/summary_all.json
# /content/drive/MyDrive/Test/Python/test_bridge_simple/summary_all.csv
#
# ==========================================================================================
# START VARIANT 6: contrastive_2x
# ==========================================================================================
# {
#   "contrastive_scale": 2.0,
#   "data_seed": 42,
#   "format_row_weight": 1,
#   "full_prompt_rows": 0,
#   "idx": 6,
#   "name": "contrastive_2x",
#   "pooling": "last",
#   "split_seed": 42,
#   "temperature": 0.05,
#   "train_seed": 48
# }
# [bridge] base train/val canonical_id overlap before skip: 0
# [bridge] skipped train rows overlapping val by canonical_id: 0
# [bridge] skipped train rows overlapping val by canonical_id: 0
# [bridge] final train/val canonical_id overlap after skip: 0
# base_rows=1046 | train_raw=883 | extra_full_prompt_train_only=0 | role_confusion_views=118 | train_after_confusion_and_oversample=1001 | val=166 | forced_format_val_ids=13 | full_prompt_val=3
# rows summary: {'expr': 200, 'rule': 800, 'format': 49, 'format_header': 3, 'format_return_condition': 4, 'format_return_block': 3, 'format_input_line': 8, 'format_input_block': 28, 'format_full_prompt_val': 3, 'total': 1049, 'canonical_groups': 1049, 'contrastive_rows': 1049}
# train_raw summary: {'expr': 171, 'rule': 679, 'format': 33, 'format_header': 2, 'format_return_condition': 2, 'format_return_block': 2, 'format_input_line': 4, 'format_input_block': 23, 'total': 883, 'canonical_groups': 883, 'contrastive_rows': 883}
# train summary: {'expr': 211, 'rule': 737, 'format': 53, 'format_header': 2, 'format_return_condition': 6, 'format_return_block': 2, 'format_input_line': 20, 'format_input_block': 23, 'role_confusion_views': 118, 'role_confusion_input_vs_atom': 6, 'role_confusion_input_vs_rule_atom': 26, 'role_confusion_expr_vs_rule_atom': 48, 'role_confusion_rule_atom_vs_return_condition': 9, 'role_confusion_iff_expr_vs_return_condition': 15, 'role_confusion_speaker_content_swap': 14, 'total': 1001, 'canonical_groups': 883, 'contrastive_rows': 1001}
# val summary: {'rule': 121, 'expr': 29, 'format': 16, 'format_header': 1, 'format_return_condition': 2, 'format_return_block': 1, 'format_input_line': 4, 'format_input_block': 5, 'format_full_prompt_val': 3, 'total': 166, 'canonical_groups': 166, 'contrastive_rows': 166}
# Loading weights:   0%|          | 0/292 [00:00<?, ?it/s]
# trainable params: 50,331,648 || all params: 1,464,979,456 || trainable%: 3.4357
# [contrastive_2x epoch 001/15] train_total=7.5937 | train_ce=2.6777 | train_ctr=0.9287 | ctr_weight=331.27 | val_top1_canon=0.9277 | val_pos=0.7983 | val_neg=0.1117 | val_ce=2.0873
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/contrastive_2x/best
# [contrastive_2x epoch 002/15] train_total=3.3501 | train_ce=1.6924 | train_ctr=0.0105 | ctr_weight=1627.56 | val_top1_canon=0.8855 | val_pos=0.6372 | val_neg=0.0268 | val_ce=1.6910
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/contrastive_2x/best
# [contrastive_2x epoch 003/15] train_total=1.9273 | train_ce=1.2840 | train_ctr=0.0036 | ctr_weight=1830.66 | val_top1_canon=0.8373 | val_pos=0.6138 | val_neg=0.0148 | val_ce=1.2177
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/contrastive_2x/best
# [contrastive_2x epoch 004/15] train_total=1.4104 | train_ce=1.0339 | train_ctr=0.0023 | ctr_weight=1888.54 | val_top1_canon=0.8554 | val_pos=0.6030 | val_neg=0.0072 | val_ce=1.1066
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/contrastive_2x/best
# [contrastive_2x epoch 005/15] train_total=1.1417 | train_ce=0.9258 | train_ctr=0.0018 | ctr_weight=1915.32 | val_top1_canon=0.7771 | val_pos=0.5420 | val_neg=-0.0094 | val_ce=1.0324
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/contrastive_2x/best
# [contrastive_2x epoch 006/15] train_total=1.3936 | train_ce=0.9186 | train_ctr=0.0018 | ctr_weight=1892.17 | val_top1_canon=0.7711 | val_pos=0.4604 | val_neg=-0.0597 | val_ce=0.9532
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/contrastive_2x/best
# [contrastive_2x epoch 007/15] train_total=1.5743 | train_ce=0.9072 | train_ctr=0.0019 | ctr_weight=1856.82 | val_top1_canon=0.6988 | val_pos=0.3557 | val_neg=-0.1570 | val_ce=1.0630
# [contrastive_2x epoch 008/15] train_total=1.9085 | train_ce=0.9506 | train_ctr=0.0023 | ctr_weight=1795.66 | val_top1_canon=0.7048 | val_pos=0.2671 | val_neg=-0.2430 | val_ce=1.0689
# [contrastive_2x epoch 009/15] train_total=1.8254 | train_ce=0.9322 | train_ctr=0.0056 | ctr_weight=1799.47 | val_top1_canon=0.6687 | val_pos=0.2313 | val_neg=-0.2837 | val_ce=1.0267
# [contrastive_2x epoch 010/15] train_total=1.8652 | train_ce=0.9472 | train_ctr=0.0050 | ctr_weight=1799.26 | val_top1_canon=0.6446 | val_pos=0.1696 | val_neg=-0.3279 | val_ce=1.0027
# [contrastive_2x epoch 011/15] train_total=1.5904 | train_ce=0.9123 | train_ctr=0.0046 | ctr_weight=1870.32 | val_top1_canon=0.6928 | val_pos=0.1512 | val_neg=-0.3516 | val_ce=0.9970
# [contrastive_2x epoch 012/15] train_total=1.5489 | train_ce=0.8971 | train_ctr=0.0079 | ctr_weight=1859.10 | val_top1_canon=0.6325 | val_pos=0.1226 | val_neg=-0.3674 | val_ce=0.9922
# [contrastive_2x epoch 013/15] train_total=1.5284 | train_ce=0.9022 | train_ctr=0.0043 | ctr_weight=1890.19 | val_top1_canon=0.6386 | val_pos=0.1354 | val_neg=-0.3645 | val_ce=0.9611
# [contrastive_2x epoch 014/15] train_total=1.4015 | train_ce=0.8823 | train_ctr=0.0041 | ctr_weight=1886.32 | val_top1_canon=0.6084 | val_pos=0.1051 | val_neg=-0.3831 | val_ce=0.9570
# [contrastive_2x epoch 015/15] train_total=1.4413 | train_ce=0.8673 | train_ctr=0.0038 | ctr_weight=1907.42 | val_top1_canon=0.6024 | val_pos=0.0912 | val_neg=-0.3911 | val_ce=0.9602
#
# DONE: contrastive_2x
# best_epoch: 6
# best_metrics: {'top1_canonical': 0.7710843373493976, 'mean_pos_sim': 0.46044921875, 'mean_neg_sim': -0.0596923828125, 'ce': 0.9532159437616188, 'contrastive_rows': 166, 'ce_only_rows': 0}
# saved best adapter to: /content/drive/MyDrive/Test/Python/test_bridge_simple/contrastive_2x/best
# saved last adapter to: /content/drive/MyDrive/Test/Python/test_bridge_simple/contrastive_2x/last
#
# Suite summary saved:
# /content/drive/MyDrive/Test/Python/test_bridge_simple/summary_all.json
# /content/drive/MyDrive/Test/Python/test_bridge_simple/summary_all.csv
#
# ==========================================================================================
# START VARIANT 9: mean_pooling
# ==========================================================================================
# {
#   "contrastive_scale": 1.0,
#   "data_seed": 42,
#   "format_row_weight": 1,
#   "full_prompt_rows": 0,
#   "idx": 9,
#   "name": "mean_pooling",
#   "pooling": "mean",
#   "split_seed": 42,
#   "temperature": 0.05,
#   "train_seed": 51
# }
# [bridge] base train/val canonical_id overlap before skip: 0
# [bridge] skipped train rows overlapping val by canonical_id: 0
# [bridge] skipped train rows overlapping val by canonical_id: 0
# [bridge] final train/val canonical_id overlap after skip: 0
# base_rows=1046 | train_raw=883 | extra_full_prompt_train_only=0 | role_confusion_views=118 | train_after_confusion_and_oversample=1001 | val=166 | forced_format_val_ids=13 | full_prompt_val=3
# rows summary: {'expr': 200, 'rule': 800, 'format': 49, 'format_header': 3, 'format_return_condition': 4, 'format_return_block': 3, 'format_input_line': 8, 'format_input_block': 28, 'format_full_prompt_val': 3, 'total': 1049, 'canonical_groups': 1049, 'contrastive_rows': 1049}
# train_raw summary: {'expr': 171, 'rule': 679, 'format': 33, 'format_header': 2, 'format_return_condition': 2, 'format_return_block': 2, 'format_input_line': 4, 'format_input_block': 23, 'total': 883, 'canonical_groups': 883, 'contrastive_rows': 883}
# train summary: {'expr': 211, 'rule': 737, 'format': 53, 'format_header': 2, 'format_return_condition': 6, 'format_return_block': 2, 'format_input_line': 20, 'format_input_block': 23, 'role_confusion_views': 118, 'role_confusion_input_vs_atom': 6, 'role_confusion_input_vs_rule_atom': 26, 'role_confusion_expr_vs_rule_atom': 48, 'role_confusion_rule_atom_vs_return_condition': 9, 'role_confusion_iff_expr_vs_return_condition': 15, 'role_confusion_speaker_content_swap': 14, 'total': 1001, 'canonical_groups': 883, 'contrastive_rows': 1001}
# val summary: {'rule': 121, 'expr': 29, 'format': 16, 'format_header': 1, 'format_return_condition': 2, 'format_return_block': 1, 'format_input_line': 4, 'format_input_block': 5, 'format_full_prompt_val': 3, 'total': 166, 'canonical_groups': 166, 'contrastive_rows': 166}
# Loading weights:   0%|          | 0/292 [00:00<?, ?it/s]
# trainable params: 50,331,648 || all params: 1,464,979,456 || trainable%: 3.4357
# [mean_pooling epoch 001/15] train_total=4.0472 | train_ce=2.0576 | train_ctr=1.5034 | ctr_weight=57.29 | val_top1_canon=0.8193 | val_pos=0.7759 | val_neg=0.3513 | val_ce=1.1873
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/mean_pooling/best
# [mean_pooling epoch 002/15] train_total=2.2177 | train_ce=1.1725 | train_ctr=0.1646 | ctr_weight=177.23 | val_top1_canon=0.8494 | val_pos=0.7275 | val_neg=0.0681 | val_ce=1.1647
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/mean_pooling/best
# [mean_pooling epoch 003/15] train_total=1.8992 | train_ce=1.0746 | train_ctr=0.0686 | ctr_weight=450.33 | val_top1_canon=0.7892 | val_pos=0.5566 | val_neg=-0.0914 | val_ce=1.0247
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/mean_pooling/best
# [mean_pooling epoch 004/15] train_total=1.7752 | train_ce=0.9928 | train_ctr=0.0637 | ctr_weight=521.68 | val_top1_canon=0.7530 | val_pos=0.5171 | val_neg=-0.1207 | val_ce=1.0393
# [mean_pooling epoch 005/15] train_total=1.6933 | train_ce=0.9479 | train_ctr=0.0586 | ctr_weight=547.33 | val_top1_canon=0.6867 | val_pos=0.3794 | val_neg=-0.2114 | val_ce=0.9557
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/mean_pooling/best
# [mean_pooling epoch 006/15] train_total=1.5948 | train_ce=0.9211 | train_ctr=0.0586 | ctr_weight=593.01 | val_top1_canon=0.6084 | val_pos=0.3105 | val_neg=-0.2617 | val_ce=0.9706
# [mean_pooling epoch 007/15] train_total=1.5912 | train_ce=0.9153 | train_ctr=0.0480 | ctr_weight=680.34 | val_top1_canon=0.6807 | val_pos=0.2483 | val_neg=-0.2993 | val_ce=0.9774
# [mean_pooling epoch 008/15] train_total=1.5315 | train_ce=0.8780 | train_ctr=0.0487 | ctr_weight=626.98 | val_top1_canon=0.7048 | val_pos=0.2520 | val_neg=-0.3027 | val_ce=0.9638
# [mean_pooling epoch 009/15] train_total=1.4687 | train_ce=0.8691 | train_ctr=0.0424 | ctr_weight=679.27 | val_top1_canon=0.5904 | val_pos=0.1863 | val_neg=-0.3396 | val_ce=0.9539
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/mean_pooling/best
# [mean_pooling epoch 010/15] train_total=1.4557 | train_ce=0.8721 | train_ctr=0.0370 | ctr_weight=752.61 | val_top1_canon=0.6084 | val_pos=0.1492 | val_neg=-0.3601 | val_ce=0.9305
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/mean_pooling/best
# [mean_pooling epoch 011/15] train_total=1.3883 | train_ce=0.8390 | train_ctr=0.0363 | ctr_weight=720.77 | val_top1_canon=0.6145 | val_pos=0.1505 | val_neg=-0.3638 | val_ce=0.9245
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/mean_pooling/best
# [mean_pooling epoch 012/15] train_total=1.3859 | train_ce=0.8357 | train_ctr=0.0367 | ctr_weight=800.98 | val_top1_canon=0.5663 | val_pos=0.1290 | val_neg=-0.3774 | val_ce=0.9103
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/mean_pooling/best
# [mean_pooling epoch 013/15] train_total=1.3550 | train_ce=0.8306 | train_ctr=0.0353 | ctr_weight=848.87 | val_top1_canon=0.5060 | val_pos=0.1262 | val_neg=-0.3796 | val_ce=0.9217
# [mean_pooling epoch 014/15] train_total=1.3186 | train_ce=0.8152 | train_ctr=0.0319 | ctr_weight=873.71 | val_top1_canon=0.5241 | val_pos=0.1184 | val_neg=-0.3838 | val_ce=0.9121
# [mean_pooling epoch 015/15] train_total=1.2883 | train_ce=0.8042 | train_ctr=0.0318 | ctr_weight=884.60 | val_top1_canon=0.4819 | val_pos=0.1140 | val_neg=-0.3870 | val_ce=0.8997
# saved best adapter by val_ce to: /content/drive/MyDrive/Test/Python/test_bridge_simple/mean_pooling/best
#
# DONE: mean_pooling
# best_epoch: 15
# best_metrics: {'top1_canonical': 0.4819277108433735, 'mean_pos_sim': 0.11395263671875, 'mean_neg_sim': -0.386962890625, 'ce': 0.8996540035109922, 'contrastive_rows': 166, 'ce_only_rows': 0}
# saved best adapter to: /content/drive/MyDrive/Test/Python/test_bridge_simple/mean_pooling/best
# saved last adapter to: /content/drive/MyDrive/Test/Python/test_bridge_simple/mean_pooling/last
#
# Suite summary saved:
# /content/drive/MyDrive/Test/Python/test_bridge_simple/summary_all.json
# /content/drive/MyDrive/Test/Python/test_bridge_simple/summary_all.csv
# [{'config': {'idx': 0,
#    'name': 'baseline',
#    'full_prompt_rows': 0,
#    'format_row_weight': 1,
#    'contrastive_scale': 1.0,
#    'temperature': 0.05,
#    'pooling': 'last',
#    'data_seed': 42,
#    'split_seed': 42,
#    'train_seed': 42},
#   'variant_dir': '/content/drive/MyDrive/Test/Python/test_bridge_simple/baseline',
#   'best_dir': '/content/drive/MyDrive/Test/Python/test_bridge_simple/baseline/best',
#   'last_dir': '/content/drive/MyDrive/Test/Python/test_bridge_simple/baseline/last',
#   'best_epoch': 15,
#   'best_score': 0.8730195344212544,
#   'best_metrics': {'top1_canonical': 0.1746987951807229,
#    'mean_pos_sim': 0.078369140625,
#    'mean_neg_sim': -0.4111328125,
#    'ce': 0.8730195344212544,
#    'contrastive_rows': 166,
#    'ce_only_rows': 0},
#   'rows_summary': {'expr': 200,
#    'rule': 800,
#    'format': 49,
#    'format_header': 3,
#    'format_return_condition': 4,
#    'format_return_block': 3,
#    'format_input_line': 8,
#    'format_input_block': 28,
#    'format_full_prompt_val': 3,
#    'total': 1049,
#    'canonical_groups': 1049,
# ...
#    'format': 86,
#    'format_header': 4,
#    'format_return_condition': 8,
#    'format_return_block': 4,
#    'format_input_line': 24,
#    'format_input_block': 46,
#    'role_confusion_views': 118,
#    'role_confusion_input_vs_atom': 6,
#    'role_confusion_input_vs_rule_atom': 26,
#    'role_confusion_expr_vs_rule_atom': 48,
#    'role_confusion_rule_atom_vs_return_condition': 9,
#    'role_confusion_iff_expr_vs_return_condition': 15,
#    'role_confusion_speaker_content_swap': 14,
#    'total': 1034,
#    'canonical_groups': 883,
#    'contrastive_rows': 1034},
#   'val_summary': {'rule': 121,
#    'expr': 29,
#    'format': 16,
#    'format_header': 1,
#    'format_return_condition': 2,
#    'format_return_block': 1,
#    'format_input_line': 4,
#    'format_input_block': 5,
#    'format_full_prompt_val': 3,
#    'total': 166,
#    'canonical_groups': 166,
#    'contrastive_rows': 166},
#   'split_protection': {'unit': 'canonical_id',
#    'base_train_val_overlap_before_skip': 0,
#    'base_skipped_train_overlap': 0,
#    'final_skipped_train_overlap': 0,
#    'final_train_val_overlap_after_skip': 0,
#    'base_train_canonical_ids': 883,
#    'base_val_canonical_ids': 166,
#    'final_train_canonical_ids': 883,
#    'final_val_canonical_ids': 166},
#   'selection_rule': 'best adapter is selected by lowest validation ce',
#   'forced_format_val_ids': 13,
#   'full_prompt_val_summary': {'format': 3,
#    'format_full_prompt_val': 3,
#    'total': 3,
#    'canonical_groups': 3,
#    'contrastive_rows': 3},
#   'elapsed_minutes': 16.539495380719504},
#  {'config': {'idx': 4,
#    'name': 'full_prompts_50_format_2x',
#    'full_prompt_rows': 50,
#    'format_row_weight': 2,
#    'contrastive_scale': 1.0,
#    'temperature': 0.05,
#    'pooling': 'last',
#    'data_seed': 42,
#    'split_seed': 42,
#    'train_seed': 46},
#   'variant_dir': '/content/drive/MyDrive/Test/Python/test_bridge_simple/full_prompts_50_format_2x',
#   'best_dir': '/content/drive/MyDrive/Test/Python/test_bridge_simple/full_prompts_50_format_2x/best',
#   'last_dir': '/content/drive/MyDrive/Test/Python/test_bridge_simple/full_prompts_50_format_2x/last',
#   'best_epoch': 15,
#   'best_score': 0.8567972463297556,
#   'best_metrics': {'top1_canonical': 0.28313253012048195,
#    'mean_pos_sim': 0.1214599609375,
#    'mean_neg_sim': -0.3701171875,
#    'ce': 0.8567972463297556,
#    'contrastive_rows': 166,
#    'ce_only_rows': 0},
#   'rows_summary': {'expr': 200,
#    'rule': 800,
#    'format': 99,
#    'format_header': 3,
#    'format_return_condition': 4,
#    'format_return_block': 3,
#    'format_input_line': 8,
#    'format_input_block': 28,
#    'format_full_prompt_val': 3,
#    'format_full_prompt': 50,
#    'total': 1099,
#    'canonical_groups': 1099,
#    'contrastive_rows': 1099},
#   'train_raw_summary': {'expr': 171,
#    'rule': 679,
#    'format': 83,
#    'format_header': 2,
#    'format_return_condition': 2,
#    'format_return_block': 2,
#    'format_input_line': 4,
#    'format_input_block': 23,
#    'format_full_prompt': 50,
#    'total': 933,
#    'canonical_groups': 933,
#    'contrastive_rows': 933},
#   'extra_full_prompt_train_only_summary': {'format': 50,
#    'format_full_prompt': 50,
#    'total': 50,
#    'canonical_groups': 50,
#    'contrastive_rows': 50},
#   'role_confusion_summary': {'role_confusion_views': 118,
#    'role_confusion_input_vs_atom': 6,
#    'format': 20,
#    'format_input_line': 16,
#    'expr': 40,
#    'role_confusion_input_vs_rule_atom': 26,
#    'rule': 58,
#    'role_confusion_expr_vs_rule_atom': 48,
#    'role_confusion_rule_atom_vs_return_condition': 9,
#    'format_return_condition': 4,
#    'role_confusion_iff_expr_vs_return_condition': 15,
#    'role_confusion_speaker_content_swap': 14,
#    'total': 118,
#    'canonical_groups': 52,
#    'contrastive_rows': 118},
#   'train_after_confusion_and_oversample_summary': {'expr': 211,
#    'rule': 737,
#    'format': 136,
#    'format_header': 4,
#    'format_return_condition': 8,
#    'format_return_block': 4,
#    'format_input_line': 24,
#    'format_input_block': 46,
#    'format_full_prompt': 50,
#    'role_confusion_views': 118,
#    'role_confusion_input_vs_atom': 6,
#    'role_confusion_input_vs_rule_atom': 26,
#    'role_confusion_expr_vs_rule_atom': 48,
#    'role_confusion_rule_atom_vs_return_condition': 9,
#    'role_confusion_iff_expr_vs_return_condition': 15,
#    'role_confusion_speaker_content_swap': 14,
#    'total': 1084,
#    'canonical_groups': 933,
#    'contrastive_rows': 1084},
#   'val_summary': {'rule': 121,
#    'expr': 29,
#    'format': 16,
#    'format_header': 1,
#    'format_return_condition': 2,
#    'format_return_block': 1,
#    'format_input_line': 4,
#    'format_input_block': 5,
#    'format_full_prompt_val': 3,
#    'total': 166,
#    'canonical_groups': 166,
#    'contrastive_rows': 166},
#   'split_protection': {'unit': 'canonical_id',
#    'base_train_val_overlap_before_skip': 0,
#    'base_skipped_train_overlap': 0,
#    'final_skipped_train_overlap': 0,
#    'final_train_val_overlap_after_skip': 0,
#    'base_train_canonical_ids': 883,
#    'base_val_canonical_ids': 166,
#    'final_train_canonical_ids': 933,
#    'final_val_canonical_ids': 166},
#   'selection_rule': 'best adapter is selected by lowest validation ce',
#   'forced_format_val_ids': 13,
#   'full_prompt_val_summary': {'format': 3,
#    'format_full_prompt_val': 3,
#    'total': 3,
#    'canonical_groups': 3,
#    'contrastive_rows': 3},
#   'elapsed_minutes': 17.051419242223105},
#  {'config': {'idx': 5,
#    'name': 'contrastive_0p5x',
#    'full_prompt_rows': 0,
#    'format_row_weight': 1,
#    'contrastive_scale': 0.5,
#    'temperature': 0.05,
#    'pooling': 'last',
#    'data_seed': 42,
#    'split_seed': 42,
#    'train_seed': 47},
#   'variant_dir': '/content/drive/MyDrive/Test/Python/test_bridge_simple/contrastive_0p5x',
#   'best_dir': '/content/drive/MyDrive/Test/Python/test_bridge_simple/contrastive_0p5x/best',
#   'last_dir': '/content/drive/MyDrive/Test/Python/test_bridge_simple/contrastive_0p5x/last',
#   'best_epoch': 14,
#   'best_score': 0.8524519707783159,
#   'best_metrics': {'top1_canonical': 0.5783132530120482,
#    'mean_pos_sim': 0.1190185546875,
#    'mean_neg_sim': -0.375244140625,
#    'ce': 0.8524519707783159,
#    'contrastive_rows': 166,
#    'ce_only_rows': 0},
#   'rows_summary': {'expr': 200,
#    'rule': 800,
#    'format': 49,
#    'format_header': 3,
#    'format_return_condition': 4,
#    'format_return_block': 3,
#    'format_input_line': 8,
#    'format_input_block': 28,
#    'format_full_prompt_val': 3,
#    'total': 1049,
#    'canonical_groups': 1049,
#    'contrastive_rows': 1049},
#   'train_raw_summary': {'expr': 171,
#    'rule': 679,
#    'format': 33,
#    'format_header': 2,
#    'format_return_condition': 2,
#    'format_return_block': 2,
#    'format_input_line': 4,
#    'format_input_block': 23,
#    'total': 883,
#    'canonical_groups': 883,
#    'contrastive_rows': 883},
#   'extra_full_prompt_train_only_summary': {'total': 0,
#    'canonical_groups': 0,
#    'contrastive_rows': 0},
#   'role_confusion_summary': {'role_confusion_views': 118,
#    'role_confusion_input_vs_atom': 6,
#    'format': 20,
#    'format_input_line': 16,
#    'expr': 40,
#    'role_confusion_input_vs_rule_atom': 26,
#    'rule': 58,
#    'role_confusion_expr_vs_rule_atom': 48,
#    'role_confusion_rule_atom_vs_return_condition': 9,
#    'format_return_condition': 4,
#    'role_confusion_iff_expr_vs_return_condition': 15,
#    'role_confusion_speaker_content_swap': 14,
#    'total': 118,
#    'canonical_groups': 52,
#    'contrastive_rows': 118},
#   'train_after_confusion_and_oversample_summary': {'expr': 211,
#    'rule': 737,
#    'format': 53,
#    'format_header': 2,
#    'format_return_condition': 6,
#    'format_return_block': 2,
#    'format_input_line': 20,
#    'format_input_block': 23,
#    'role_confusion_views': 118,
#    'role_confusion_input_vs_atom': 6,
#    'role_confusion_input_vs_rule_atom': 26,
#    'role_confusion_expr_vs_rule_atom': 48,
#    'role_confusion_rule_atom_vs_return_condition': 9,
#    'role_confusion_iff_expr_vs_return_condition': 15,
#    'role_confusion_speaker_content_swap': 14,
#    'total': 1001,
#    'canonical_groups': 883,
#    'contrastive_rows': 1001},
#   'val_summary': {'rule': 121,
#    'expr': 29,
#    'format': 16,
#    'format_header': 1,
#    'format_return_condition': 2,
#    'format_return_block': 1,
#    'format_input_line': 4,
#    'format_input_block': 5,
#    'format_full_prompt_val': 3,
#    'total': 166,
#    'canonical_groups': 166,
#    'contrastive_rows': 166},
#   'split_protection': {'unit': 'canonical_id',
#    'base_train_val_overlap_before_skip': 0,
#    'base_skipped_train_overlap': 0,
#    'final_skipped_train_overlap': 0,
#    'final_train_val_overlap_after_skip': 0,
#    'base_train_canonical_ids': 883,
#    'base_val_canonical_ids': 166,
#    'final_train_canonical_ids': 883,
#    'final_val_canonical_ids': 166},
#   'selection_rule': 'best adapter is selected by lowest validation ce',
#   'forced_format_val_ids': 13,
#   'full_prompt_val_summary': {'format': 3,
#    'format_full_prompt_val': 3,
#    'total': 3,
#    'canonical_groups': 3,
#    'contrastive_rows': 3},
#   'elapsed_minutes': 16.36795228322347},
#  {'config': {'idx': 6,
#    'name': 'contrastive_2x',
#    'full_prompt_rows': 0,
#    'format_row_weight': 1,
#    'contrastive_scale': 2.0,
#    'temperature': 0.05,
#    'pooling': 'last',
#    'data_seed': 42,
#    'split_seed': 42,
#    'train_seed': 48},
#   'variant_dir': '/content/drive/MyDrive/Test/Python/test_bridge_simple/contrastive_2x',
#   'best_dir': '/content/drive/MyDrive/Test/Python/test_bridge_simple/contrastive_2x/best',
#   'last_dir': '/content/drive/MyDrive/Test/Python/test_bridge_simple/contrastive_2x/last',
#   'best_epoch': 6,
#   'best_score': 0.9532159437616188,
#   'best_metrics': {'top1_canonical': 0.7710843373493976,
#    'mean_pos_sim': 0.46044921875,
#    'mean_neg_sim': -0.0596923828125,
#    'ce': 0.9532159437616188,
#    'contrastive_rows': 166,
#    'ce_only_rows': 0},
#   'rows_summary': {'expr': 200,
#    'rule': 800,
#    'format': 49,
#    'format_header': 3,
#    'format_return_condition': 4,
#    'format_return_block': 3,
#    'format_input_line': 8,
#    'format_input_block': 28,
#    'format_full_prompt_val': 3,
#    'total': 1049,
#    'canonical_groups': 1049,
#    'contrastive_rows': 1049},
#   'train_raw_summary': {'expr': 171,
#    'rule': 679,
#    'format': 33,
#    'format_header': 2,
#    'format_return_condition': 2,
#    'format_return_block': 2,
#    'format_input_line': 4,
#    'format_input_block': 23,
#    'total': 883,
#    'canonical_groups': 883,
#    'contrastive_rows': 883},
#   'extra_full_prompt_train_only_summary': {'total': 0,
#    'canonical_groups': 0,
#    'contrastive_rows': 0},
#   'role_confusion_summary': {'role_confusion_views': 118,
#    'role_confusion_input_vs_atom': 6,
#    'format': 20,
#    'format_input_line': 16,
#    'expr': 40,
#    'role_confusion_input_vs_rule_atom': 26,
#    'rule': 58,
#    'role_confusion_expr_vs_rule_atom': 48,
#    'role_confusion_rule_atom_vs_return_condition': 9,
#    'format_return_condition': 4,
#    'role_confusion_iff_expr_vs_return_condition': 15,
#    'role_confusion_speaker_content_swap': 14,
#    'total': 118,
#    'canonical_groups': 52,
#    'contrastive_rows': 118},
#   'train_after_confusion_and_oversample_summary': {'expr': 211,
#    'rule': 737,
#    'format': 53,
#    'format_header': 2,
#    'format_return_condition': 6,
#    'format_return_block': 2,
#    'format_input_line': 20,
#    'format_input_block': 23,
#    'role_confusion_views': 118,
#    'role_confusion_input_vs_atom': 6,
#    'role_confusion_input_vs_rule_atom': 26,
#    'role_confusion_expr_vs_rule_atom': 48,
#    'role_confusion_rule_atom_vs_return_condition': 9,
#    'role_confusion_iff_expr_vs_return_condition': 15,
#    'role_confusion_speaker_content_swap': 14,
#    'total': 1001,
#    'canonical_groups': 883,
#    'contrastive_rows': 1001},
#   'val_summary': {'rule': 121,
#    'expr': 29,
#    'format': 16,
#    'format_header': 1,
#    'format_return_condition': 2,
#    'format_return_block': 1,
#    'format_input_line': 4,
#    'format_input_block': 5,
#    'format_full_prompt_val': 3,
#    'total': 166,
#    'canonical_groups': 166,
#    'contrastive_rows': 166},
#   'split_protection': {'unit': 'canonical_id',
#    'base_train_val_overlap_before_skip': 0,
#    'base_skipped_train_overlap': 0,
#    'final_skipped_train_overlap': 0,
#    'final_train_val_overlap_after_skip': 0,
#    'base_train_canonical_ids': 883,
#    'base_val_canonical_ids': 166,
#    'final_train_canonical_ids': 883,
#    'final_val_canonical_ids': 166},
#   'selection_rule': 'best adapter is selected by lowest validation ce',
#   'forced_format_val_ids': 13,
#   'full_prompt_val_summary': {'format': 3,
#    'format_full_prompt_val': 3,
#    'total': 3,
#    'canonical_groups': 3,
#    'contrastive_rows': 3},
#   'elapsed_minutes': 16.507700363794964},
#  {'config': {'idx': 9,
#    'name': 'mean_pooling',
#    'full_prompt_rows': 0,
#    'format_row_weight': 1,
#    'contrastive_scale': 1.0,
#    'temperature': 0.05,
#    'pooling': 'mean',
#    'data_seed': 42,
#    'split_seed': 42,
#    'train_seed': 51},
#   'variant_dir': '/content/drive/MyDrive/Test/Python/test_bridge_simple/mean_pooling',
#   'best_dir': '/content/drive/MyDrive/Test/Python/test_bridge_simple/mean_pooling/best',
#   'last_dir': '/content/drive/MyDrive/Test/Python/test_bridge_simple/mean_pooling/last',
#   'best_epoch': 15,
#   'best_score': 0.8996540035109922,
#   'best_metrics': {'top1_canonical': 0.4819277108433735,
#    'mean_pos_sim': 0.11395263671875,
#    'mean_neg_sim': -0.386962890625,
#    'ce': 0.8996540035109922,
#    'contrastive_rows': 166,
#    'ce_only_rows': 0},
#   'rows_summary': {'expr': 200,
#    'rule': 800,
#    'format': 49,
#    'format_header': 3,
#    'format_return_condition': 4,
#    'format_return_block': 3,
#    'format_input_line': 8,
#    'format_input_block': 28,
#    'format_full_prompt_val': 3,
#    'total': 1049,
#    'canonical_groups': 1049,
#    'contrastive_rows': 1049},
#   'train_raw_summary': {'expr': 171,
#    'rule': 679,
#    'format': 33,
#    'format_header': 2,
#    'format_return_condition': 2,
#    'format_return_block': 2,
#    'format_input_line': 4,
#    'format_input_block': 23,
#    'total': 883,
#    'canonical_groups': 883,
#    'contrastive_rows': 883},
#   'extra_full_prompt_train_only_summary': {'total': 0,
#    'canonical_groups': 0,
#    'contrastive_rows': 0},
#   'role_confusion_summary': {'role_confusion_views': 118,
#    'role_confusion_input_vs_atom': 6,
#    'format': 20,
#    'format_input_line': 16,
#    'expr': 40,
#    'role_confusion_input_vs_rule_atom': 26,
#    'rule': 58,
#    'role_confusion_expr_vs_rule_atom': 48,
#    'role_confusion_rule_atom_vs_return_condition': 9,
#    'format_return_condition': 4,
#    'role_confusion_iff_expr_vs_return_condition': 15,
#    'role_confusion_speaker_content_swap': 14,
#    'total': 118,
#    'canonical_groups': 52,
#    'contrastive_rows': 118},
#   'train_after_confusion_and_oversample_summary': {'expr': 211,
#    'rule': 737,
#    'format': 53,
#    'format_header': 2,
#    'format_return_condition': 6,
#    'format_return_block': 2,
#    'format_input_line': 20,
#    'format_input_block': 23,
#    'role_confusion_views': 118,
#    'role_confusion_input_vs_atom': 6,
#    'role_confusion_input_vs_rule_atom': 26,
#    'role_confusion_expr_vs_rule_atom': 48,
#    'role_confusion_rule_atom_vs_return_condition': 9,
#    'role_confusion_iff_expr_vs_return_condition': 15,
#    'role_confusion_speaker_content_swap': 14,
#    'total': 1001,
#    'canonical_groups': 883,
#    'contrastive_rows': 1001},
#   'val_summary': {'rule': 121,
#    'expr': 29,
#    'format': 16,
#    'format_header': 1,
#    'format_return_condition': 2,
#    'format_return_block': 1,
#    'format_input_line': 4,
#    'format_input_block': 5,
#    'format_full_prompt_val': 3,
#    'total': 166,
#    'canonical_groups': 166,
#    'contrastive_rows': 166},
#   'split_protection': {'unit': 'canonical_id',
#    'base_train_val_overlap_before_skip': 0,
#    'base_skipped_train_overlap': 0,
#    'final_skipped_train_overlap': 0,
#    'final_train_val_overlap_after_skip': 0,
#    'base_train_canonical_ids': 883,
#    'base_val_canonical_ids': 166,
#    'final_train_canonical_ids': 883,
#    'final_val_canonical_ids': 166},
#   'selection_rule': 'best adapter is selected by lowest validation ce',
#   'forced_format_val_ids': 13,
#   'full_prompt_val_summary': {'format': 3,
#    'format_full_prompt_val': 3,
#    'total': 3,
#    'canonical_groups': 3,
#    'contrastive_rows': 3},
#   'elapsed_minutes': 16.62864444255829}]
